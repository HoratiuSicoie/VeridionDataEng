# %%
import pandas as pd
import os
import numpy as np
import re

# %%
#!pip install ace_tools

# %%
base_dir = os.path.dirname(os.getcwd())
data_path = os.path.join(base_dir, 'data', 'veridion_product_deduplication_challenge.snappy.parquet')

#load parquet file
df = pd.read_parquet(data_path)

#preview
df.head()
# Out:
#                                               unspsc           root_domain  \
# 0  Sewing and stitchery and weaving equipment and...     studio-atcoat.com
# 1             Electric alternating current AC motors        worm-gears.net
# 2                 Vehicle trim and exterior covering  customcarcoverco.com
# 3                                    Pipe connectors       plumbmaster.com
# 4                                              Doors              sogno.in
#
#                                             page_url  \
# 0      https://studio-atcoat.com/1372696759/?idx=510
# 1          https://worm-gears.net/tag/worm-gear-box/
# 2  https://customcarcoverco.com/collections/vendo...
# 3  https://www.plumbmaster.com/search?q=wolverine...
# 4  http://www.sogno.in/product-detail-CST-HGD-331...
#
#                       product_title  \
# 0       Glimakra Warping Board (8m)
# 1           NMRV Worm Gearbox Motor
# 2          Nissan R33 GTR Car Cover
# 3                 Flexible Fittings
# 4  CST-HGD-33103 Hinged Closet Door
#
#                                      product_summary        product_name  \
# 0  The Glimakra Warping Board is designed for use...       Warping Board
# 1  The NMRV Worm Gearbox Motor is a high-efficien...  Worm Gearbox Motor
# 2  A custom car cover designed for the Nissan R33...           Car Cover
# 3  Flexible fittings for plumbing applications, a...   Flexible Fittings
# 4  The CST-HGD-33103 Hinged Closet Door is a meti...  Hinged Closet Door
#
#   product_identifier brand              intended_industries  \
# 0                 []  None                        [Textile]
# 1                 []  None                     [Industrial]
# 2                 []  None                     [Automotive]
# 3                 []  None                       [Plumbing]
# 4                 []   CST  [Home Appliances, Construction]
#
#                              applicability  ... form  \
# 0                   [use with floor looms]  ...   []
# 1                [industrial applications]  ...   []
# 2  [protecting vehicles from the elements]  ...   []
# 3                 [plumbing installations]  ...   []
# 4                         [Closet Storage]  ...   []
#
#                                                 size  \
# 0  [{'dimension': 'Length', 'qualitative': False,...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                color purity energy_efficiency  \
# 0                                                 []     []              None
# 1  [{'original': 'Blue', 'simple': 'Blue'}, {'ori...     []              None
# 2                                                 []     []              None
# 3                                                 []     []              None
# 4                                                 []     []              None
#
#   pressure_rating                                       power_rating  \
# 0              []                                                 []
# 1              []  [{'qualitative': False, 'type': 'min', 'unit':...
# 2              []                                                 []
# 3              []                                                 []
# 4              []                                                 []
#
#    quality_standards_and_certifications  \
# 0                                    []
# 1                                    []
# 2                                    []
# 3                                    []
# 4                                    []
#
#                               miscellaneous_features  \
# 0                                                 []
# 1  [Omnibearing installation, High radiation effi...
# 2  [Personalization with custom brand logos, grap...
# 3  [allows for movement, flexibility in installat...
# 4  [Italian craftsmanship, German engineering, Sm...
#
#                                          description
# 0  The "Warping Board" is designed for use with f...
# 1  The "Worm Gearbox Motor" is a high-efficiency ...
# 2  The "Car Cover" is a custom-designed cover tai...
# 3  "Flexible Fittings" are designed for plumbing ...
# 4  The "Hinged Closet Door" is a storage solution...
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 1.  Explore Data

# %%
df.shape
# Out:
# (21946, 31)

# %%
df.columns
# Out:
# Index(['unspsc', 'root_domain', 'page_url', 'product_title', 'product_summary',
#        'product_name', 'product_identifier', 'brand', 'intended_industries',
#        'applicability', 'eco_friendly', 'ethical_and_sustainability_practices',
#        'production_capacity', 'price', 'materials', 'ingredients',
#        'manufacturing_countries', 'manufacturing_year', 'manufacturing_type',
#        'customization', 'packaging_type', 'form', 'size', 'color', 'purity',
#        'energy_efficiency', 'pressure_rating', 'power_rating',
#        'quality_standards_and_certifications', 'miscellaneous_features',
#        'description'],
#       dtype='object')

# %%
# Missing value detector- not only NaN's in the dataset but also empty lists, dicts strings etc.
def is_effectively_missing(x):
    if isinstance(x, (list, np.ndarray)):
        return len(x) == 0
    elif pd.isnull(x):
        return True
    elif isinstance(x, str) and x.strip() == '':
        return True
    return False

# Apply the function to detect missing values
missing_counts = df.applymap(is_effectively_missing).sum()
missing_percent = (missing_counts / len(df)) * 100

missing_df = pd.DataFrame({
    'Missing Count': missing_counts,
    'Missing %': missing_percent.round(2)
}).sort_values(by='Missing Count', ascending=False)


display(missing_df)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_9936\635080358.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   missing_counts = df.applymap(is_effectively_missing).sum()
#                                       Missing Count  Missing %
# production_capacity                           21911      99.84
# purity                                        21773      99.21
# energy_efficiency                             21769      99.19
# ethical_and_sustainability_practices          21586      98.36
# form                                          21447      97.73
# power_rating                                  21379      97.42
# pressure_rating                               21370      97.38
# ingredients                                   21337      97.23
# manufacturing_type                            21280      96.97
# eco_friendly                                  20977      95.58
# quality_standards_and_certifications          20966      95.53
# packaging_type                                20957      95.49
# manufacturing_countries                       20889      95.18
# product_identifier                            20072      91.46
# customization                                 19622      89.41
# color                                         19404      88.42
# materials                                     16619      75.73
# size                                          16428      74.86
# price                                         15424      70.28
# brand                                         14884      67.82
# miscellaneous_features                        10701      48.76
# applicability                                  5859      26.70
# intended_industries                            2230      10.16
# product_summary                                1185       5.40
# description                                    1171       5.34
# product_name                                     36       0.16
# product_title                                     0       0.00
# page_url                                          0       0.00
# root_domain                                       0       0.00
# unspsc                                            0       0.00
# manufacturing_year                                0       0.00

# %%
#reduce noise- decide threshold value 91.46% missing values to drop completely 
#product identifier 91.46 as threshold as given by name might still be useful for enrichment
columns_to_drop = [
    'production_capacity', 'purity', 'energy_efficiency', 'ethical_and_sustainability_practices',
    'form', 'power_rating', 'pressure_rating', 'ingredients', 'manufacturing_type',
    'eco_friendly', 'quality_standards_and_certifications', 'packaging_type',
    'manufacturing_countries'
]
df = df.drop(columns=columns_to_drop)

# %%
#keep ones from 67 to 91.46 just for enrichment as they still might be informative post-clustering, not for core deduplication logic
df.shape
# Out:
# (21946, 18)

# %% [markdown]
# ## 2.  Preprocessing:
#
# I will address the scalability issues in the modular code, this notebook is just a representation for the workflow of the project

# %%
df.head(n=5)
# Out:
#                                               unspsc           root_domain  \
# 0  Sewing and stitchery and weaving equipment and...     studio-atcoat.com
# 1             Electric alternating current AC motors        worm-gears.net
# 2                 Vehicle trim and exterior covering  customcarcoverco.com
# 3                                    Pipe connectors       plumbmaster.com
# 4                                              Doors              sogno.in
#
#                                             page_url  \
# 0      https://studio-atcoat.com/1372696759/?idx=510
# 1          https://worm-gears.net/tag/worm-gear-box/
# 2  https://customcarcoverco.com/collections/vendo...
# 3  https://www.plumbmaster.com/search?q=wolverine...
# 4  http://www.sogno.in/product-detail-CST-HGD-331...
#
#                       product_title  \
# 0       Glimakra Warping Board (8m)
# 1           NMRV Worm Gearbox Motor
# 2          Nissan R33 GTR Car Cover
# 3                 Flexible Fittings
# 4  CST-HGD-33103 Hinged Closet Door
#
#                                      product_summary        product_name  \
# 0  The Glimakra Warping Board is designed for use...       Warping Board
# 1  The NMRV Worm Gearbox Motor is a high-efficien...  Worm Gearbox Motor
# 2  A custom car cover designed for the Nissan R33...           Car Cover
# 3  Flexible fittings for plumbing applications, a...   Flexible Fittings
# 4  The CST-HGD-33103 Hinged Closet Door is a meti...  Hinged Closet Door
#
#   product_identifier brand              intended_industries  \
# 0                 []  None                        [Textile]
# 1                 []  None                     [Industrial]
# 2                 []  None                     [Automotive]
# 3                 []  None                       [Plumbing]
# 4                 []   CST  [Home Appliances, Construction]
#
#                              applicability  \
# 0                   [use with floor looms]
# 1                [industrial applications]
# 2  [protecting vehicles from the elements]
# 3                 [plumbing installations]
# 4                         [Closet Storage]
#
#                                                price materials  \
# 0  [{'amount': 159000.0, 'currency': 'KRW', 'type...        []
# 1                                                 []        []
# 2                                                 []        []
# 3                                                 []        []
# 4                                                 []        []
#
#    manufacturing_year                                      customization  \
# 0                  -1                                                 []
# 1                  -1                                                 []
# 2                  -1  [Customizable with custom brand logos, graphic...
# 3                  -1                                                 []
# 4                  -1                                                 []
#
#                                                 size  \
# 0  [{'dimension': 'Length', 'qualitative': False,...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                color  \
# 0                                                 []
# 1  [{'original': 'Blue', 'simple': 'Blue'}, {'ori...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                               miscellaneous_features  \
# 0                                                 []
# 1  [Omnibearing installation, High radiation effi...
# 2  [Personalization with custom brand logos, grap...
# 3  [allows for movement, flexibility in installat...
# 4  [Italian craftsmanship, German engineering, Sm...
#
#                                          description
# 0  The "Warping Board" is designed for use with f...
# 1  The "Worm Gearbox Motor" is a high-efficiency ...
# 2  The "Car Cover" is a custom-designed cover tai...
# 3  "Flexible Fittings" are designed for plumbing ...
# 4  The "Hinged Closet Door" is a storage solution...

# %%
from collections import Counter

for col in df.columns:
    sample = df[col].dropna().head(100)  # sample first 100 non-null entries
    types = [type(x).__name__ for x in sample]
    type_counts = Counter(types)
    print(f"{col}: {dict(type_counts)}")
# Out:
# unspsc: {'str': 100}
# root_domain: {'str': 100}
# page_url: {'str': 100}
# product_title: {'str': 100}
# product_summary: {'str': 100}
# product_name: {'str': 100}
# product_identifier: {'ndarray': 100}
# brand: {'str': 100}
# intended_industries: {'ndarray': 100}
# applicability: {'ndarray': 100}
# price: {'ndarray': 100}
# materials: {'ndarray': 100}
# manufacturing_year: {'int': 100}
# customization: {'ndarray': 100}
# size: {'ndarray': 100}
# color: {'ndarray': 100}
# miscellaneous_features: {'ndarray': 100}
# description: {'str': 100}

# %%
#First- text normalization.
#for str apply to all except punctuation for root domain+ url
import re

def normalize_text(text, remove_punct=True):
    if isinstance(text, str):
        text = text.lower()
        if remove_punct:
            text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
        text = text.replace('\n', ' ')
        text = re.sub(r'\s+', ' ', text).strip()
        return text
    return ""

text_columns = ['product_title', 'product_summary', 'product_name','unspsc','description']

for col in text_columns:
    df[col] = df[col].apply(lambda x: normalize_text(x, remove_punct=True))
    
def normalize_product_identifier(val):
    if isinstance(val, (list, np.ndarray)):
        if len(val) == 0:
            return np.nan
        cleaned = [normalize_text(x) for x in val if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

df['product_identifier'] = df['product_identifier'].apply(normalize_product_identifier)
df['brand'] = df['brand'].apply(lambda x: normalize_text(x, remove_punct=True) if isinstance(x, str) else np.nan)

def normalize_array_field(arr):
    if isinstance(arr, (list, np.ndarray)):
        cleaned = [normalize_text(x) for x in arr if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

#If we are dealing WITH LARGE DATA. care with apply here, I will change the approach in the modular implementation
df['intended_industries'] = df['intended_industries'].apply(normalize_array_field)
df['applicability'] = df['applicability'].apply(normalize_array_field)

def extract_price_amount(x):
    if isinstance(x, np.ndarray) and len(x) > 0 and isinstance(x[0], dict):
        return x[0].get('amount', np.nan)
    return np.nan

def extract_price_currency(x):
    if isinstance(x, np.ndarray) and len(x) > 0 and isinstance(x[0], dict):
        return normalize_text(x[0].get('currency', ''), remove_punct=False)
    return np.nan

def extract_price_type(x):
    if isinstance(x, np.ndarray) and len(x) > 0 and isinstance(x[0], dict):
        return normalize_text(x[0].get('type', ''), remove_punct=True)
    return np.nan

# Apply extraction
df['price_amount'] = df['price'].apply(extract_price_amount)
df['price_currency'] = df['price'].apply(extract_price_currency)
df['price_type'] = df['price'].apply(extract_price_type)


df.drop(columns=['price'], inplace=True)


df['price_amount'] = pd.to_numeric(df['price_amount'], errors='coerce').astype('float64').round(2)

def normalize_materials(arr):
    if isinstance(arr, (list, np.ndarray)):
        cleaned = [normalize_text(x) for x in arr if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

df['materials'] = df['materials'].apply(normalize_materials)
df.drop(columns=['manufacturing_year'], inplace=True)

df.head(n=7)
# Out:
#                                               unspsc  \
# 0  sewing and stitchery and weaving equipment and...
# 1             electric alternating current ac motors
# 2                 vehicle trim and exterior covering
# 3                                    pipe connectors
# 4                                              doors
# 5                                    faucets or taps
# 6                                   dispensing tools
#
#                   root_domain  \
# 0           studio-atcoat.com
# 1              worm-gears.net
# 2        customcarcoverco.com
# 3             plumbmaster.com
# 4                    sogno.in
# 5             plumbmaster.com
# 6  advancedpressuresystems.ca
#
#                                             page_url  \
# 0      https://studio-atcoat.com/1372696759/?idx=510
# 1          https://worm-gears.net/tag/worm-gear-box/
# 2  https://customcarcoverco.com/collections/vendo...
# 3  https://www.plumbmaster.com/search?q=wolverine...
# 4  http://www.sogno.in/product-detail-CST-HGD-331...
# 5  https://www.plumbmaster.com/search?q=wolverine...
# 6  https://advancedpressuresystems.ca/collections...
#
#                          product_title  \
# 0            glimakra warping board 8m
# 1              nmrv worm gearbox motor
# 2             nissan r33 gtr car cover
# 3                    flexible fittings
# 4       csthgd33103 hinged closet door
# 5                         deep faucets
# 6  10k dry shutoff gun handle assembly
#
#                                      product_summary  \
# 0  the glimakra warping board is designed for use...
# 1  the nmrv worm gearbox motor is a highefficienc...
# 2  a custom car cover designed for the nissan r33...
# 3  flexible fittings for plumbing applications al...
# 4  the csthgd33103 hinged closet door is a meticu...
# 5  faucets with a deep design providing a secure ...
# 6  the 10k dry shutoff gun handle assembly is a c...
#
#                       product_name product_identifier brand  \
# 0                    warping board                NaN   NaN
# 1               worm gearbox motor                NaN   NaN
# 2                        car cover                NaN   NaN
# 3                flexible fittings                NaN   NaN
# 4               hinged closet door                NaN   cst
# 5                     deep faucets                NaN   NaN
# 6  dry shutoff gun handle assembly                NaN   NaN
#
#              intended_industries                           applicability  \
# 0                        textile                    use with floor looms
# 1                     industrial                 industrial applications
# 2                     automotive   protecting vehicles from the elements
# 3                       plumbing                  plumbing installations
# 4  construction, home appliances                          closet storage
# 5                       plumbing                                     NaN
# 6                  manufacturing  highpressure water blasting operations
#
#   materials                                      customization  \
# 0       NaN                                                 []
# 1       NaN                                                 []
# 2       NaN  [Customizable with custom brand logos, graphic...
# 3       NaN                                                 []
# 4       NaN                                                 []
# 5       NaN                                                 []
# 6       NaN                                                 []
#
#                                                 size  \
# 0  [{'dimension': 'Length', 'qualitative': False,...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
#
#                                                color  \
# 0                                                 []
# 1  [{'original': 'Blue', 'simple': 'Blue'}, {'ori...
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
#
#                               miscellaneous_features  \
# 0                                                 []
# 1  [Omnibearing installation, High radiation effi...
# 2  [Personalization with custom brand logos, grap...
# 3  [allows for movement, flexibility in installat...
# 4  [Italian craftsmanship, German engineering, Sm...
# 5        [deep design, secure and stable connection]
# 6                                                 []
#
#                                          description  price_amount  \
# 0  the warping board is designed for use with flo...      159000.0
# 1  the worm gearbox motor is a highefficiency gea...           NaN
# 2  the car cover is a customdesigned cover tailor...           NaN
# 3  flexible fittings are designed for plumbing ap...           NaN
# 4  the hinged closet door is a storage solution c...           NaN
# 5  deep faucets are designed with a deep design t...           NaN
# 6  the dry shutoff gun handle assembly is a compo...           NaN
#
#   price_currency price_type
# 0            krw      exact
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN

# %%
def normalize_customization(arr):
    if isinstance(arr, (list, np.ndarray)):
        cleaned = [normalize_text(x) for x in arr if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

df['customization'] = df['customization'].apply(normalize_customization)

def normalize_misc_features(arr):
    if isinstance(arr, (list, np.ndarray)):
        cleaned = [normalize_text(x) for x in arr if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

df['miscellaneous_features'] = df['miscellaneous_features'].apply(normalize_misc_features)

# %%
df.head(n=7)
# Out:
#                                               unspsc  \
# 0  sewing and stitchery and weaving equipment and...
# 1             electric alternating current ac motors
# 2                 vehicle trim and exterior covering
# 3                                    pipe connectors
# 4                                              doors
# 5                                    faucets or taps
# 6                                   dispensing tools
#
#                   root_domain  \
# 0           studio-atcoat.com
# 1              worm-gears.net
# 2        customcarcoverco.com
# 3             plumbmaster.com
# 4                    sogno.in
# 5             plumbmaster.com
# 6  advancedpressuresystems.ca
#
#                                             page_url  \
# 0      https://studio-atcoat.com/1372696759/?idx=510
# 1          https://worm-gears.net/tag/worm-gear-box/
# 2  https://customcarcoverco.com/collections/vendo...
# 3  https://www.plumbmaster.com/search?q=wolverine...
# 4  http://www.sogno.in/product-detail-CST-HGD-331...
# 5  https://www.plumbmaster.com/search?q=wolverine...
# 6  https://advancedpressuresystems.ca/collections...
#
#                          product_title  \
# 0            glimakra warping board 8m
# 1              nmrv worm gearbox motor
# 2             nissan r33 gtr car cover
# 3                    flexible fittings
# 4       csthgd33103 hinged closet door
# 5                         deep faucets
# 6  10k dry shutoff gun handle assembly
#
#                                      product_summary  \
# 0  the glimakra warping board is designed for use...
# 1  the nmrv worm gearbox motor is a highefficienc...
# 2  a custom car cover designed for the nissan r33...
# 3  flexible fittings for plumbing applications al...
# 4  the csthgd33103 hinged closet door is a meticu...
# 5  faucets with a deep design providing a secure ...
# 6  the 10k dry shutoff gun handle assembly is a c...
#
#                       product_name product_identifier brand  \
# 0                    warping board                NaN   NaN
# 1               worm gearbox motor                NaN   NaN
# 2                        car cover                NaN   NaN
# 3                flexible fittings                NaN   NaN
# 4               hinged closet door                NaN   cst
# 5                     deep faucets                NaN   NaN
# 6  dry shutoff gun handle assembly                NaN   NaN
#
#              intended_industries                           applicability  \
# 0                        textile                    use with floor looms
# 1                     industrial                 industrial applications
# 2                     automotive   protecting vehicles from the elements
# 3                       plumbing                  plumbing installations
# 4  construction, home appliances                          closet storage
# 5                       plumbing                                     NaN
# 6                  manufacturing  highpressure water blasting operations
#
#   materials                                      customization  \
# 0       NaN                                                NaN
# 1       NaN                                                NaN
# 2       NaN  customizable with custom brand logos graphics ...
# 3       NaN                                                NaN
# 4       NaN                                                NaN
# 5       NaN                                                NaN
# 6       NaN                                                NaN
#
#                                                 size  \
# 0  [{'dimension': 'Length', 'qualitative': False,...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
#
#                                                color  \
# 0                                                 []
# 1  [{'original': 'Blue', 'simple': 'Blue'}, {'ori...
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
#
#                               miscellaneous_features  \
# 0                                                NaN
# 1  good service life, high radiation efficiency, ...
# 2  personalization with custom brand logos graphi...
# 3   allows for movement, flexibility in installation
# 4  german engineering, italian craftsmanship, smo...
# 5          deep design, secure and stable connection
# 6                                                NaN
#
#                                          description  price_amount  \
# 0  the warping board is designed for use with flo...      159000.0
# 1  the worm gearbox motor is a highefficiency gea...           NaN
# 2  the car cover is a customdesigned cover tailor...           NaN
# 3  flexible fittings are designed for plumbing ap...           NaN
# 4  the hinged closet door is a storage solution c...           NaN
# 5  deep faucets are designed with a deep design t...           NaN
# 6  the dry shutoff gun handle assembly is a compo...           NaN
#
#   price_currency price_type
# 0            krw      exact
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN

# %%
# unique_colors = df['color'].dropna().apply(str).unique().tolist()
# unique_colors.sort()
# for color in unique_colors:
#     print(color)
# #they seem to have the same format. original -simple.
def normalize_color(arr):
    if isinstance(arr, (list, np.ndarray)):
        values = []
        for entry in arr:
            if isinstance(entry, dict):
                val = entry.get('simple') or entry.get('original')
                if val:
                    values.append(normalize_text(val))
        return ', '.join(sorted(set(values))) if values else np.nan
    return np.nan

df['color'] = df['color'].apply(normalize_color)

# %%
unique_sizes = df['size'].dropna().apply(str).unique().tolist()
unique_sizes.sort()
for size in unique_sizes:
    print(size)
# Out:
# []
# [{'dimension': 'Area', 'qualitative': False, 'type': 'exact', 'unit': 'ft2', 'value': '1500'}]
# [{'dimension': 'Area', 'qualitative': False, 'type': 'exact', 'unit': 'ft2', 'value': '700'}]
# [{'dimension': 'Area', 'qualitative': False, 'type': 'exact', 'unit': 'in2', 'value': '254'}]
# [{'dimension': 'Area', 'qualitative': False, 'type': 'exact', 'unit': 'in2', 'value': '4'}]
# [{'dimension': 'Area', 'qualitative': False, 'type': 'exact', 'unit': 'm2', 'value': '1'}]
# [{'dimension': 'Area', 'qualitative': False, 'type': 'exact', 'unit': 'm2', 'value': '1.76'}]
# [{'dimension': 'Area', 'qualitative': False, 'type': 'exact', 'unit': 'm2', 'value': '100'}]
# [{'dimension': 'Area', 'qualitative': False, 'type': 'exact', 'unit': 'm2', 'value': '18'}]
# [{'dimension': 'Area', 'qualitative': False, 'type': 'exact', 'unit': 'm2', 'value': '500'}]
# [{'dimension': 'Area', 'qualitative': False, 'type': 'max', 'unit': 'ft2', 'value': '1800'}
#  {'dimension': 'Area', 'qualitative': False, 'type': 'min', 'unit': 'ft2', 'value': '1093'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '60'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '7.5'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.3125'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.13'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.5'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.75'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '10'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '11.2'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '20.5'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '34.2'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '121.2'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '11.2'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '20.5'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '34.2'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '19.0'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '34'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '18.5'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '13'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '22.25'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '33.25'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '37.5'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '48'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '23'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '36.5'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '35.5'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24.38'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '50'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '23.38'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.062'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '10'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '2.75'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.2'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.4'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.1'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'oz', 'value': '4.23'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '33'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '20'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.125'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.75'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.1'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.75'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '11'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.9'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.7'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.3'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.9'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '35.8'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '26.4'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '64.59'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9.8'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '14.3'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '11'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8.86'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '11.61'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '31.3'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '22.71'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8.98'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '12.64'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '38.23'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '29.98'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '128'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '185'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '59'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'kg', 'value': '0.6'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '160'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '260'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '25'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '122'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'kg', 'value': '0.17'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '305'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '500'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '55'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '750'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '3'}
#  {'dimension': 'Depth', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '4'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '8.5'}
#  {'dimension': 'Depth', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '13.5'}]
# [{'dimension': 'Depth', 'qualitative': False, 'type': 'min', 'unit': 'mm', 'value': '150'}
#  {'dimension': 'Depth', 'qualitative': False, 'type': 'max', 'unit': 'mm', 'value': '225'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '50'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '138.8'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '21'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '27'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '28'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '29'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '3'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '3.8'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '30'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '38.1'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '47'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '49'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '14'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '5.4'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '50'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '55'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '58'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '62'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '7'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '10'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '5'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '2'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.03125'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.035'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '144'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.073'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.0938'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.4375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.095'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '145'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.104'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '15'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.1094'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.125'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '100'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.125'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '32'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.125'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '1.25'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '2.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.13'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.005'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.1719'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.625'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.1875'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.1563'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.1875'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.032'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.1875'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.2'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.22'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.2344'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.25'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '20'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.25'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.1875'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.25'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.25'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.25'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1500'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.257'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.312'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.3125'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.3125'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.335'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.41'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '223'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.65'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '18'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.96'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1524'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5625'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.625'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.63'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.656'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.75'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.75'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '2.25'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.75'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'mm', 'value': '17'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'mm', 'value': '46'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.8125'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '10'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.875'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '42'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '96'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.0'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.125'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.125'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.15'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '0.16'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.1875'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.25'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.29'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '10'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.3'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '12'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.3'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.3125'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '12'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '72'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.375'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.0625'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.4'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.8'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.8'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.8'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '15'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '18.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '14'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '18'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.56'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.6'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.625'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.67'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.875'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.9375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '10'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8.5'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '10'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '11.75'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '36'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '48'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '12'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '12.188'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.093'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '13'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.25'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '13'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.5'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '10.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '13'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '13.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '13.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '14'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '15'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '15.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '15.6'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '15.75'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '30.125'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '16'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '36'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '48'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '16'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '17'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '17.2'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.147'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.04'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '18'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '18.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '18'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '7.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '18'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '19'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.625'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '10.63'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '19'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'm', 'value': '40'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.5'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '44'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.6'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '7.41'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.604'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.765'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '0.57'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.75'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.0625'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '20'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '20'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '22'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '40'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '22'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '10'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '22'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '26'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '42'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '145'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '26'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.116'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.125'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.25'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.25'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.3'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6.1'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.3'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'oz', 'value': '1.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.3'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '30'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.75'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '15'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '32'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '17.126'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '19.291'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '31.496'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '54.0133'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '32'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '10.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '10'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'ft', 'value': '20'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '24'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '36'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '48'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '55'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.0'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.125'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.25'}
#  {'dimension': 'Depth', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.3'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.5'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.06'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '4.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '40'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '44'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '48'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '29'}
#  {'dimension': 'Weight', 'qualitative': False, 'type': 'exact', 'unit': 'lbs', 'value': '55'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '48'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '13.11'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '6'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '22'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.63'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '50'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '12'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6.35'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '6.58'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '60'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '1.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '7'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '7.25'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '7.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '7.75'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9.625'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '7.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '72.3'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '103.2'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.375'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '5.375'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8'}
#  {'dimension': 'Thickness', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '0.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.543'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '3.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '8'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9.25'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '2.14'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9.25'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'in', 'value': '36'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'in', 'value': '48'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '9.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'in', 'value': '92'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'm', 'value': '3.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '0.16'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '0.42'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'min', 'unit': 'mm', 'value': '1.142'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'max', 'unit': 'mm', 'value': '3.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '0.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '0.8'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '0.9'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.0'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.1'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.14'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.18'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.3'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '20'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.5'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'cm', 'value': '28'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.55'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.6'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.75'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.93'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '2.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '1.93'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '3.2'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '10'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '10.5'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '100'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '101'}
#  {'dimension': 'Height', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '52'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '11'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '110'}
#  {'dimension': 'Length', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '3205'}]
# [{'dimension': 'Diameter', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '110'}
#  {'dimension': 'Width', 'qualitative': False, 'type': 'exact', 'unit': 'mm', 'value': '12'}]
# ...
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '00'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '12'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '00-12'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '08-12'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '00-12'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '13'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '04'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '11'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '04-6'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '10-13'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '04-6'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '11-13'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '06-8'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '10-13'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '06-8'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '9-11'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '0805'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '1210'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '09'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '11'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '09'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '13'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '09-11'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '10-13'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '14'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '22'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '28'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '32'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '2XS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '6XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '3'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '15'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '30A'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '40C'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '32B'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '40B'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '32B'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '40C'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '32B'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '42C'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '34D'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '44D'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '38'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '44'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '40'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '46'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '42.5'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '44.5'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '5g'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '9g'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': '9-11'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '10-13'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'A4'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'A5'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Adult'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Child'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'CN0116S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'CN0116XXL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Extra Large'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Cocktail'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Extra Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Extra Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Extra Wide'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Large/Extra Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Junior Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'X-Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'L'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '6XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Large'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '6X'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Large'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XLT'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'M'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '4X'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'M'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '4XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'M'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '5X'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'M'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '5XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'M'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'L'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '3X'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '5X'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '6X'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Six'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Sixth'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XLT'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XXL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'PAR20'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'PAR38'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '2XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '3X'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '3XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '4XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '5X'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '5XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'L'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XXL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S/M'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'L/XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'S/M'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XXL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Single Shot'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Double Shot'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '3X-Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '4X-Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Extra Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Extra-Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'X-Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XX-Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XXLarge'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Synth 2.0'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Synth 3.1'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'Twin'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'Full'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'US 6'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'US 11'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'X-Small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XX-Large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XL'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '3XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XL'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XXL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '2XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '3XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '4XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'L'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XXL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XXXL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XXS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': '8XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XXS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'XXS'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'XXXL'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'medium'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'large'}]
# [{'dimension': None, 'qualitative': True, 'type': 'min', 'unit': None, 'value': 'small'}
#  {'dimension': None, 'qualitative': True, 'type': 'max', 'unit': None, 'value': 'large'}]

# %%
def normalize_size_field(arr):
    if isinstance(arr, (list, np.ndarray)) and len(arr) > 0:
        parts = []
        for entry in arr:
            if isinstance(entry, dict):
                dim = normalize_text(entry.get('dimension', ''), remove_punct=False)
                val = normalize_text(entry.get('value', ''), remove_punct=False)
                unit = normalize_text(entry.get('unit', ''), remove_punct=False)
                typ = normalize_text(entry.get('type', ''), remove_punct=False)

                if dim and val and unit:
                    label = f"{dim}: {typ} {val} {unit}" if typ else f"{dim}: {val} {unit}"
                    parts.append(label.strip())
        return ', '.join(parts) if parts else np.nan
    return np.nan

df['size'] = df['size'].apply(normalize_size_field)

# %%
df
# Out:
#                                                   unspsc  \
# 0      sewing and stitchery and weaving equipment and...
# 1                 electric alternating current ac motors
# 2                     vehicle trim and exterior covering
# 3                                        pipe connectors
# 4                                                  doors
# ...                                                  ...
# 21941                                              other
# 21942                     processed and synthetic rubber
# 21943                            fresh cut rose bouquets
# 21944  vision correction or cosmetic eyewear and rela...
# 21945       chocolate and sugars and sweetening products
#
#                          root_domain  \
# 0                  studio-atcoat.com
# 1                     worm-gears.net
# 2               customcarcoverco.com
# 3                    plumbmaster.com
# 4                           sogno.in
# ...                              ...
# 21941                   dsbridal.com
# 21942               50735-in.all.biz
# 21943             lilyofthevalley.uk
# 21944  getcontactlensesonline.com.au
# 21945           malagoschocolate.com
#
#                                                 page_url  \
# 0          https://studio-atcoat.com/1372696759/?idx=510
# 1              https://worm-gears.net/tag/worm-gear-box/
# 2      https://customcarcoverco.com/collections/vendo...
# 3      https://www.plumbmaster.com/search?q=wolverine...
# 4      http://www.sogno.in/product-detail-CST-HGD-331...
# ...                                                  ...
# 21941  https://www.dsbridal.com/index.php/sale/veils....
# 21942               https://50735-in.all.biz/group-goods
# 21943  https://www.lilyofthevalley.uk/product/luxurio...
# 21944  https://getcontactlensesonline.com.au/brand/al...
# 21945  https://malagoschocolate.com/collections/ready...
#
#                                      product_title  \
# 0                        glimakra warping board 8m
# 1                          nmrv worm gearbox motor
# 2                         nissan r33 gtr car cover
# 3                                flexible fittings
# 4                   csthgd33103 hinged closet door
# ...                                            ...
# 21941                             1516 accessories
# 21942              general mechanical rubber goods
# 21943                        luxurious rose garden
# 21944  dailies aquacomfort plus multifocal 30 pack
# 21945  signature dark collection 85 dark chocolate
#
#                                          product_summary  \
# 0      the glimakra warping board is designed for use...
# 1      the nmrv worm gearbox motor is a highefficienc...
# 2      a custom car cover designed for the nissan r33...
# 3      flexible fittings for plumbing applications al...
# 4      the csthgd33103 hinged closet door is a meticu...
# ...                                                  ...
# 21941  accessories designed for sweet 1516 available ...
# 21942  a category of rubber goods designed for genera...
# 21943  the luxurious rose garden is a stunning floral...
# 21944  a pack of 30 dailies aquacomfort plus multifoc...
# 21945  a signature dark collection product from malag...
#
#                     product_name product_identifier  \
# 0                  warping board                NaN
# 1             worm gearbox motor                NaN
# 2                      car cover                NaN
# 3              flexible fittings                NaN
# 4             hinged closet door                NaN
# ...                          ...                ...
# 21941                accessories                NaN
# 21942               rubber goods                NaN
# 21943         floral arrangement                NaN
# 21944  multifocal contact lenses                NaN
# 21945             dark chocolate                NaN
#
#                             brand            intended_industries  \
# 0                             NaN                        textile
# 1                             NaN                     industrial
# 2                             NaN                     automotive
# 3                             NaN                       plumbing
# 4                             cst  construction, home appliances
# ...                           ...                            ...
# 21941                         NaN                         retail
# 21942                         NaN                  manufacturing
# 21943  lily of the valley florist                  gifts, retail
# 21944                     dailies                     healthcare
# 21945           malagos chocolate                  food beverage
#
#                                applicability materials  \
# 0                       use with floor looms       NaN
# 1                    industrial applications       NaN
# 2      protecting vehicles from the elements       NaN
# 3                     plumbing installations       NaN
# 4                             closet storage       NaN
# ...                                      ...       ...
# 21941             accessories for sweet 1516       NaN
# 21942                                    NaN    rubber
# 21943           decorative purposes, gifting       NaN
# 21944                      vision correction       NaN
# 21945                                    NaN       NaN
#
#                                            customization  \
# 0                                                    NaN
# 1                                                    NaN
# 2      customizable with custom brand logos graphics ...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 21941                                                NaN
# 21942                                                NaN
# 21943                                                NaN
# 21944                                                NaN
# 21945                                                NaN
#
#                                             size       color  \
# 0                              length: exact 8 m         NaN
# 1                                            NaN  blue, gray
# 2                                            NaN         NaN
# 3                                            NaN         NaN
# 4                                            NaN         NaN
# ...                                          ...         ...
# 21941                      diameter: exact 15 in         NaN
# 21942                                        NaN         NaN
# 21943  width: exact 250 cm, height: exact 250 cm         NaN
# 21944                                        NaN         NaN
# 21945                                        NaN         NaN
#
#                                   miscellaneous_features  \
# 0                                                    NaN
# 1      good service life, high radiation efficiency, ...
# 2      personalization with custom brand logos graphi...
# 3       allows for movement, flexibility in installation
# 4      german engineering, italian craftsmanship, smo...
# ...                                                  ...
# 21941                        part of the sale collection
# 21942                                                NaN
# 21943    product images available in various resolutions
# 21944                                                NaN
# 21945                                                NaN
#
#                                              description  price_amount  \
# 0      the warping board is designed for use with flo...      159000.0
# 1      the worm gearbox motor is a highefficiency gea...           NaN
# 2      the car cover is a customdesigned cover tailor...           NaN
# 3      flexible fittings are designed for plumbing ap...           NaN
# 4      the hinged closet door is a storage solution c...           NaN
# ...                                                  ...           ...
# 21941  accessories are designed for use with sweet 15...           NaN
# 21942  rubber goods are designed for general mechanic...           NaN
# 21943  the floral arrangement offered by lily of the ...          45.0
# 21944  multifocal contact lenses are designed for dai...          82.0
# 21945  dark chocolate from malagos chocolate is a ric...           NaN
#
#       price_currency price_type
# 0                krw      exact
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
# ...              ...        ...
# 21941            NaN        NaN
# 21942            NaN        NaN
# 21943            gbp        min
# 21944            usd      exact
# 21945            NaN        NaN
#
# [21946 rows x 19 columns]

# %%
import os

os.makedirs("../Data", exist_ok=True)
df.to_csv("../Data/cleaned_products.csv", index=False)

#for local use

# %%
import os

os.makedirs("../Data", exist_ok=True)
df.to_parquet("../Data/cleaned_products.parquet", index=False)

#for cluster use
