# %%
import pandas as pd
import os
import numpy as np
import re

# %%
#!pip install ace_tools

# %%
base_dir = os.path.dirname(os.getcwd())
data_path = os.path.join(base_dir, 'data', 'veridion_product_deduplication_challenge.snappy.parquet')

#load parquet file
df = pd.read_parquet(data_path)

#preview
df.head()
# Out:
#                                               unspsc           root_domain  \
# 0  Sewing and stitchery and weaving equipment and...     studio-atcoat.com
# 1             Electric alternating current AC motors        worm-gears.net
# 2                 Vehicle trim and exterior covering  customcarcoverco.com
# 3                                    Pipe connectors       plumbmaster.com
# 4                                              Doors              sogno.in
#
#                                             page_url  \
# 0      https://studio-atcoat.com/1372696759/?idx=510
# 1          https://worm-gears.net/tag/worm-gear-box/
# 2  https://customcarcoverco.com/collections/vendo...
# 3  https://www.plumbmaster.com/search?q=wolverine...
# 4  http://www.sogno.in/product-detail-CST-HGD-331...
#
#                       product_title  \
# 0       Glimakra Warping Board (8m)
# 1           NMRV Worm Gearbox Motor
# 2          Nissan R33 GTR Car Cover
# 3                 Flexible Fittings
# 4  CST-HGD-33103 Hinged Closet Door
#
#                                      product_summary        product_name  \
# 0  The Glimakra Warping Board is designed for use...       Warping Board
# 1  The NMRV Worm Gearbox Motor is a high-efficien...  Worm Gearbox Motor
# 2  A custom car cover designed for the Nissan R33...           Car Cover
# 3  Flexible fittings for plumbing applications, a...   Flexible Fittings
# 4  The CST-HGD-33103 Hinged Closet Door is a meti...  Hinged Closet Door
#
#   product_identifier brand              intended_industries  \
# 0                 []  None                        [Textile]
# 1                 []  None                     [Industrial]
# 2                 []  None                     [Automotive]
# 3                 []  None                       [Plumbing]
# 4                 []   CST  [Home Appliances, Construction]
#
#                              applicability  ... form  \
# 0                   [use with floor looms]  ...   []
# 1                [industrial applications]  ...   []
# 2  [protecting vehicles from the elements]  ...   []
# 3                 [plumbing installations]  ...   []
# 4                         [Closet Storage]  ...   []
#
#                                                 size  \
# 0  [{'dimension': 'Length', 'qualitative': False,...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                color purity energy_efficiency  \
# 0                                                 []     []              None
# 1  [{'original': 'Blue', 'simple': 'Blue'}, {'ori...     []              None
# 2                                                 []     []              None
# 3                                                 []     []              None
# 4                                                 []     []              None
#
#   pressure_rating                                       power_rating  \
# 0              []                                                 []
# 1              []  [{'qualitative': False, 'type': 'min', 'unit':...
# 2              []                                                 []
# 3              []                                                 []
# 4              []                                                 []
#
#    quality_standards_and_certifications  \
# 0                                    []
# 1                                    []
# 2                                    []
# 3                                    []
# 4                                    []
#
#                               miscellaneous_features  \
# 0                                                 []
# 1  [Omnibearing installation, High radiation effi...
# 2  [Personalization with custom brand logos, grap...
# 3  [allows for movement, flexibility in installat...
# 4  [Italian craftsmanship, German engineering, Sm...
#
#                                          description
# 0  The "Warping Board" is designed for use with f...
# 1  The "Worm Gearbox Motor" is a high-efficiency ...
# 2  The "Car Cover" is a custom-designed cover tai...
# 3  "Flexible Fittings" are designed for plumbing ...
# 4  The "Hinged Closet Door" is a storage solution...
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 1.  Explore Data

# %%
df.shape
# Out:
# (21946, 31)

# %%
df.columns
# Out:
# Index(['unspsc', 'root_domain', 'page_url', 'product_title', 'product_summary',
#        'product_name', 'product_identifier', 'brand', 'intended_industries',
#        'applicability', 'eco_friendly', 'ethical_and_sustainability_practices',
#        'production_capacity', 'price', 'materials', 'ingredients',
#        'manufacturing_countries', 'manufacturing_year', 'manufacturing_type',
#        'customization', 'packaging_type', 'form', 'size', 'color', 'purity',
#        'energy_efficiency', 'pressure_rating', 'power_rating',
#        'quality_standards_and_certifications', 'miscellaneous_features',
#        'description'],
#       dtype='object')

# %%
# Missing value detector- not only NaN's in the dataset but also empty lists, dicts strings etc.
def is_effectively_missing(x):
    if isinstance(x, (list, np.ndarray)):
        return len(x) == 0
    elif pd.isnull(x):
        return True
    elif isinstance(x, str) and x.strip() == '':
        return True
    return False

# Apply the function to detect missing values
missing_counts = df.applymap(is_effectively_missing).sum()
missing_percent = (missing_counts / len(df)) * 100

missing_df = pd.DataFrame({
    'Missing Count': missing_counts,
    'Missing %': missing_percent.round(2)
}).sort_values(by='Missing Count', ascending=False)


display(missing_df)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_27372\2833059944.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   missing_counts = df.applymap(is_effectively_missing).sum()
#                                       Missing Count  Missing %
# production_capacity                           21911      99.84
# purity                                        21773      99.21
# energy_efficiency                             21769      99.19
# ethical_and_sustainability_practices          21586      98.36
# form                                          21447      97.73
# power_rating                                  21379      97.42
# pressure_rating                               21370      97.38
# ingredients                                   21337      97.23
# manufacturing_type                            21280      96.97
# eco_friendly                                  20977      95.58
# quality_standards_and_certifications          20966      95.53
# packaging_type                                20957      95.49
# manufacturing_countries                       20889      95.18
# product_identifier                            20072      91.46
# customization                                 19622      89.41
# color                                         19404      88.42
# materials                                     16619      75.73
# size                                          16428      74.86
# price                                         15424      70.28
# brand                                         14884      67.82
# miscellaneous_features                        10701      48.76
# applicability                                  5859      26.70
# intended_industries                            2230      10.16
# product_summary                                1185       5.40
# description                                    1171       5.34
# product_name                                     36       0.16
# product_title                                     0       0.00
# page_url                                          0       0.00
# root_domain                                       0       0.00
# unspsc                                            0       0.00
# manufacturing_year                                0       0.00

# %%
#reduce noise- decide threshold value 91.46% missing values to drop completely 
#product identifier 91.46 as threshold as given by name might still be useful for enrichment
columns_to_drop = [
    'production_capacity', 'purity', 'energy_efficiency', 'ethical_and_sustainability_practices',
    'form', 'power_rating', 'pressure_rating', 'ingredients', 'manufacturing_type',
    'eco_friendly', 'quality_standards_and_certifications', 'packaging_type',
    'manufacturing_countries'
]
df = df.drop(columns=columns_to_drop)

# %%
#keep ones from 67 to 91.46 just for enrichment as they still might be informative post-clustering, not for core deduplication logic
df.shape
# Out:
# (21946, 18)

# %% [markdown]
# ## 2.  Preprocessing:
#
# I will address the scalability issues in the modular code, this notebook is just a representation for the workflow of the project

# %%
df.head(n=5)
# Out:
#                                               unspsc           root_domain  \
# 0  Sewing and stitchery and weaving equipment and...     studio-atcoat.com
# 1             Electric alternating current AC motors        worm-gears.net
# 2                 Vehicle trim and exterior covering  customcarcoverco.com
# 3                                    Pipe connectors       plumbmaster.com
# 4                                              Doors              sogno.in
#
#                                             page_url  \
# 0      https://studio-atcoat.com/1372696759/?idx=510
# 1          https://worm-gears.net/tag/worm-gear-box/
# 2  https://customcarcoverco.com/collections/vendo...
# 3  https://www.plumbmaster.com/search?q=wolverine...
# 4  http://www.sogno.in/product-detail-CST-HGD-331...
#
#                       product_title  \
# 0       Glimakra Warping Board (8m)
# 1           NMRV Worm Gearbox Motor
# 2          Nissan R33 GTR Car Cover
# 3                 Flexible Fittings
# 4  CST-HGD-33103 Hinged Closet Door
#
#                                      product_summary        product_name  \
# 0  The Glimakra Warping Board is designed for use...       Warping Board
# 1  The NMRV Worm Gearbox Motor is a high-efficien...  Worm Gearbox Motor
# 2  A custom car cover designed for the Nissan R33...           Car Cover
# 3  Flexible fittings for plumbing applications, a...   Flexible Fittings
# 4  The CST-HGD-33103 Hinged Closet Door is a meti...  Hinged Closet Door
#
#   product_identifier brand              intended_industries  \
# 0                 []  None                        [Textile]
# 1                 []  None                     [Industrial]
# 2                 []  None                     [Automotive]
# 3                 []  None                       [Plumbing]
# 4                 []   CST  [Home Appliances, Construction]
#
#                              applicability  \
# 0                   [use with floor looms]
# 1                [industrial applications]
# 2  [protecting vehicles from the elements]
# 3                 [plumbing installations]
# 4                         [Closet Storage]
#
#                                                price materials  \
# 0  [{'amount': 159000.0, 'currency': 'KRW', 'type...        []
# 1                                                 []        []
# 2                                                 []        []
# 3                                                 []        []
# 4                                                 []        []
#
#    manufacturing_year                                      customization  \
# 0                  -1                                                 []
# 1                  -1                                                 []
# 2                  -1  [Customizable with custom brand logos, graphic...
# 3                  -1                                                 []
# 4                  -1                                                 []
#
#                                                 size  \
# 0  [{'dimension': 'Length', 'qualitative': False,...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                color  \
# 0                                                 []
# 1  [{'original': 'Blue', 'simple': 'Blue'}, {'ori...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                               miscellaneous_features  \
# 0                                                 []
# 1  [Omnibearing installation, High radiation effi...
# 2  [Personalization with custom brand logos, grap...
# 3  [allows for movement, flexibility in installat...
# 4  [Italian craftsmanship, German engineering, Sm...
#
#                                          description
# 0  The "Warping Board" is designed for use with f...
# 1  The "Worm Gearbox Motor" is a high-efficiency ...
# 2  The "Car Cover" is a custom-designed cover tai...
# 3  "Flexible Fittings" are designed for plumbing ...
# 4  The "Hinged Closet Door" is a storage solution...

# %%
from collections import Counter

for col in df.columns:
    sample = df[col].dropna().head(100)  # sample first 100 non-null entries
    types = [type(x).__name__ for x in sample]
    type_counts = Counter(types)
    print(f"{col}: {dict(type_counts)}")
# Out:
# unspsc: {'str': 100}
# root_domain: {'str': 100}
# page_url: {'str': 100}
# product_title: {'str': 100}
# product_summary: {'str': 100}
# product_name: {'str': 100}
# product_identifier: {'ndarray': 100}
# brand: {'str': 100}
# intended_industries: {'ndarray': 100}
# applicability: {'ndarray': 100}
# price: {'ndarray': 100}
# materials: {'ndarray': 100}
# manufacturing_year: {'int': 100}
# customization: {'ndarray': 100}
# size: {'ndarray': 100}
# color: {'ndarray': 100}
# miscellaneous_features: {'ndarray': 100}
# description: {'str': 100}

# %%
#First- text normalization.
#for str apply to all except punctuation for root domain+ url
import re

def normalize_text(text, remove_punct=True):
    if isinstance(text, str):
        text = text.lower()
        if remove_punct:
            text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
        text = text.replace('\n', ' ')
        text = re.sub(r'\s+', ' ', text).strip()
        return text
    return ""

text_columns = ['product_title', 'product_summary', 'product_name','unspsc','description']

for col in text_columns:
    df[col] = df[col].apply(lambda x: normalize_text(x, remove_punct=True))
    
def normalize_product_identifier(val):
    if isinstance(val, (list, np.ndarray)):
        if len(val) == 0:
            return np.nan
        cleaned = [normalize_text(x) for x in val if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

df['product_identifier'] = df['product_identifier'].apply(normalize_product_identifier)
df['brand'] = df['brand'].apply(lambda x: normalize_text(x, remove_punct=True) if isinstance(x, str) else np.nan)

def normalize_array_field(arr):
    if isinstance(arr, (list, np.ndarray)):
        cleaned = [normalize_text(x) for x in arr if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

#If we are dealing WITH LARGE DATA. care with apply here, I will change the approach in the modular implementation
df['intended_industries'] = df['intended_industries'].apply(normalize_array_field)
df['applicability'] = df['applicability'].apply(normalize_array_field)

def extract_price_amount(x):
    if isinstance(x, np.ndarray) and len(x) > 0 and isinstance(x[0], dict):
        return x[0].get('amount', np.nan)
    return np.nan

def extract_price_currency(x):
    if isinstance(x, np.ndarray) and len(x) > 0 and isinstance(x[0], dict):
        return normalize_text(x[0].get('currency', ''), remove_punct=False)
    return np.nan

def extract_price_type(x):
    if isinstance(x, np.ndarray) and len(x) > 0 and isinstance(x[0], dict):
        return normalize_text(x[0].get('type', ''), remove_punct=True)
    return np.nan

# Apply extraction
df['price_amount'] = df['price'].apply(extract_price_amount)
df['price_currency'] = df['price'].apply(extract_price_currency)
df['price_type'] = df['price'].apply(extract_price_type)


df.drop(columns=['price'], inplace=True)


df['price_amount'] = pd.to_numeric(df['price_amount'], errors='coerce').astype('float64').round(2)

def normalize_materials(arr):
    if isinstance(arr, (list, np.ndarray)):
        cleaned = [normalize_text(x) for x in arr if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

df['materials'] = df['materials'].apply(normalize_materials)
df.drop(columns=['manufacturing_year'], inplace=True)

df.head(n=7)
# Out:
#                                               unspsc  \
# 0  sewing and stitchery and weaving equipment and...
# 1             electric alternating current ac motors
# 2                 vehicle trim and exterior covering
# 3                                    pipe connectors
# 4                                              doors
# 5                                    faucets or taps
# 6                                   dispensing tools
#
#                   root_domain  \
# 0           studio-atcoat.com
# 1              worm-gears.net
# 2        customcarcoverco.com
# 3             plumbmaster.com
# 4                    sogno.in
# 5             plumbmaster.com
# 6  advancedpressuresystems.ca
#
#                                             page_url  \
# 0      https://studio-atcoat.com/1372696759/?idx=510
# 1          https://worm-gears.net/tag/worm-gear-box/
# 2  https://customcarcoverco.com/collections/vendo...
# 3  https://www.plumbmaster.com/search?q=wolverine...
# 4  http://www.sogno.in/product-detail-CST-HGD-331...
# 5  https://www.plumbmaster.com/search?q=wolverine...
# 6  https://advancedpressuresystems.ca/collections...
#
#                          product_title  \
# 0            glimakra warping board 8m
# 1              nmrv worm gearbox motor
# 2             nissan r33 gtr car cover
# 3                    flexible fittings
# 4       csthgd33103 hinged closet door
# 5                         deep faucets
# 6  10k dry shutoff gun handle assembly
#
#                                      product_summary  \
# 0  the glimakra warping board is designed for use...
# 1  the nmrv worm gearbox motor is a highefficienc...
# 2  a custom car cover designed for the nissan r33...
# 3  flexible fittings for plumbing applications al...
# 4  the csthgd33103 hinged closet door is a meticu...
# 5  faucets with a deep design providing a secure ...
# 6  the 10k dry shutoff gun handle assembly is a c...
#
#                       product_name product_identifier brand  \
# 0                    warping board                NaN   NaN
# 1               worm gearbox motor                NaN   NaN
# 2                        car cover                NaN   NaN
# 3                flexible fittings                NaN   NaN
# 4               hinged closet door                NaN   cst
# 5                     deep faucets                NaN   NaN
# 6  dry shutoff gun handle assembly                NaN   NaN
#
#              intended_industries                           applicability  \
# 0                        textile                    use with floor looms
# 1                     industrial                 industrial applications
# 2                     automotive   protecting vehicles from the elements
# 3                       plumbing                  plumbing installations
# 4  construction, home appliances                          closet storage
# 5                       plumbing                                     NaN
# 6                  manufacturing  highpressure water blasting operations
#
#   materials                                      customization  \
# 0       NaN                                                 []
# 1       NaN                                                 []
# 2       NaN  [Customizable with custom brand logos, graphic...
# 3       NaN                                                 []
# 4       NaN                                                 []
# 5       NaN                                                 []
# 6       NaN                                                 []
#
#                                                 size  \
# 0  [{'dimension': 'Length', 'qualitative': False,...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
#
#                                                color  \
# 0                                                 []
# 1  [{'original': 'Blue', 'simple': 'Blue'}, {'ori...
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
#
#                               miscellaneous_features  \
# 0                                                 []
# 1  [Omnibearing installation, High radiation effi...
# 2  [Personalization with custom brand logos, grap...
# 3  [allows for movement, flexibility in installat...
# 4  [Italian craftsmanship, German engineering, Sm...
# 5        [deep design, secure and stable connection]
# 6                                                 []
#
#                                          description  price_amount  \
# 0  the warping board is designed for use with flo...      159000.0
# 1  the worm gearbox motor is a highefficiency gea...           NaN
# 2  the car cover is a customdesigned cover tailor...           NaN
# 3  flexible fittings are designed for plumbing ap...           NaN
# 4  the hinged closet door is a storage solution c...           NaN
# 5  deep faucets are designed with a deep design t...           NaN
# 6  the dry shutoff gun handle assembly is a compo...           NaN
#
#   price_currency price_type
# 0            krw      exact
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN

# %%
def normalize_customization(arr):
    if isinstance(arr, (list, np.ndarray)):
        cleaned = [normalize_text(x) for x in arr if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

df['customization'] = df['customization'].apply(normalize_customization)

def normalize_misc_features(arr):
    if isinstance(arr, (list, np.ndarray)):
        cleaned = [normalize_text(x) for x in arr if isinstance(x, str) and x.strip()]
        return ', '.join(sorted(set(cleaned))) if cleaned else np.nan
    return np.nan

df['miscellaneous_features'] = df['miscellaneous_features'].apply(normalize_misc_features)

# %%
df.head(n=7)
# Out:
#                                               unspsc  \
# 0  sewing and stitchery and weaving equipment and...
# 1             electric alternating current ac motors
# 2                 vehicle trim and exterior covering
# 3                                    pipe connectors
# 4                                              doors
# 5                                    faucets or taps
# 6                                   dispensing tools
#
#                   root_domain  \
# 0           studio-atcoat.com
# 1              worm-gears.net
# 2        customcarcoverco.com
# 3             plumbmaster.com
# 4                    sogno.in
# 5             plumbmaster.com
# 6  advancedpressuresystems.ca
#
#                                             page_url  \
# 0      https://studio-atcoat.com/1372696759/?idx=510
# 1          https://worm-gears.net/tag/worm-gear-box/
# 2  https://customcarcoverco.com/collections/vendo...
# 3  https://www.plumbmaster.com/search?q=wolverine...
# 4  http://www.sogno.in/product-detail-CST-HGD-331...
# 5  https://www.plumbmaster.com/search?q=wolverine...
# 6  https://advancedpressuresystems.ca/collections...
#
#                          product_title  \
# 0            glimakra warping board 8m
# 1              nmrv worm gearbox motor
# 2             nissan r33 gtr car cover
# 3                    flexible fittings
# 4       csthgd33103 hinged closet door
# 5                         deep faucets
# 6  10k dry shutoff gun handle assembly
#
#                                      product_summary  \
# 0  the glimakra warping board is designed for use...
# 1  the nmrv worm gearbox motor is a highefficienc...
# 2  a custom car cover designed for the nissan r33...
# 3  flexible fittings for plumbing applications al...
# 4  the csthgd33103 hinged closet door is a meticu...
# 5  faucets with a deep design providing a secure ...
# 6  the 10k dry shutoff gun handle assembly is a c...
#
#                       product_name product_identifier brand  \
# 0                    warping board                NaN   NaN
# 1               worm gearbox motor                NaN   NaN
# 2                        car cover                NaN   NaN
# 3                flexible fittings                NaN   NaN
# 4               hinged closet door                NaN   cst
# 5                     deep faucets                NaN   NaN
# 6  dry shutoff gun handle assembly                NaN   NaN
#
#              intended_industries                           applicability  \
# 0                        textile                    use with floor looms
# 1                     industrial                 industrial applications
# 2                     automotive   protecting vehicles from the elements
# 3                       plumbing                  plumbing installations
# 4  construction, home appliances                          closet storage
# 5                       plumbing                                     NaN
# 6                  manufacturing  highpressure water blasting operations
#
#   materials  customization                                               size  \
# 0       NaN            NaN  [{'dimension': 'Length', 'qualitative': False,...
# 1       NaN            NaN                                                 []
# 2       NaN            NaN                                                 []
# 3       NaN            NaN                                                 []
# 4       NaN            NaN                                                 []
# 5       NaN            NaN                                                 []
# 6       NaN            NaN                                                 []
#
#                                                color  \
# 0                                                 []
# 1  [{'original': 'Blue', 'simple': 'Blue'}, {'ori...
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
#
#                               miscellaneous_features  \
# 0                                                NaN
# 1  good service life, high radiation efficiency, ...
# 2  personalization with custom brand logos graphi...
# 3   allows for movement, flexibility in installation
# 4  german engineering, italian craftsmanship, smo...
# 5          deep design, secure and stable connection
# 6                                                NaN
#
#                                          description  price_amount  \
# 0  the warping board is designed for use with flo...      159000.0
# 1  the worm gearbox motor is a highefficiency gea...           NaN
# 2  the car cover is a customdesigned cover tailor...           NaN
# 3  flexible fittings are designed for plumbing ap...           NaN
# 4  the hinged closet door is a storage solution c...           NaN
# 5  deep faucets are designed with a deep design t...           NaN
# 6  the dry shutoff gun handle assembly is a compo...           NaN
#
#   price_currency price_type
# 0            krw      exact
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN

# %%
# unique_colors = df['color'].dropna().apply(str).unique().tolist()
# unique_colors.sort()
# for color in unique_colors:
#     print(color)
# #they seem to have the same format. original -simple.
def normalize_color(arr):
    if isinstance(arr, (list, np.ndarray)):
        values = []
        for entry in arr:
            if isinstance(entry, dict):
                val = entry.get('simple') or entry.get('original')
                if val:
                    values.append(normalize_text(val))
        return ', '.join(sorted(set(values))) if values else np.nan
    return np.nan

df['color'] = df['color'].apply(normalize_color)

# %%
unique_sizes = df['size'].dropna().apply(str).unique().tolist()
unique_sizes.sort()
for size in unique_sizes:
    print(size)
# Out:
# area: exact 1 m2
# area: exact 1.76 m2
# area: exact 100 m2
# area: exact 1500 ft2
# area: exact 18 m2
# area: exact 254 in2
# area: exact 4 in2
# area: exact 500 m2
# area: exact 700 ft2
# area: max 1800 ft2, area: min 1093 ft2
# depth: exact 0.3125 in
# depth: exact 1.13 in, height: exact 3.5 in, width: exact 0.75 in
# depth: exact 10 in
# depth: exact 11.2 in, width: exact 20.5 in, height: exact 34.2 in
# depth: exact 11.2 in, width: exact 20.5 in, height: exact 34.2 in, weight: exact 121.2 lbs
# depth: exact 128 mm, length: exact 185 mm, width: exact 59 mm, weight: exact 0.6 kg
# depth: exact 160 mm
# depth: exact 19.0 in, height: exact 34 in, width: exact 18.5 in
# depth: exact 2 in, width: exact 6 in, height: exact 13 in
# depth: exact 22.25 in, height: exact 33.25 in, width: exact 37.5 in
# depth: exact 24 in, height: exact 48 in, width: exact 24 in
# depth: exact 24 in, width: exact 23 in, height: exact 36.5 in
# depth: exact 24 in, width: exact 24 in, height: exact 35.5 in
# depth: exact 24.38 in, height: exact 50 in, width: exact 23.38 in
# depth: exact 260 mm, length: exact 25 mm, width: exact 122 mm, weight: exact 0.17 kg
# depth: exact 3 in, width: exact 4 in
# depth: exact 3.062 in, height: exact 10 ft, width: exact 2.75 ft
# depth: exact 305 mm
# depth: exact 4.2 in, height: exact 0.4 in, width: exact 4.1 in, weight: exact 4.23 oz
# depth: exact 5 in, height: exact 33 in, weight: exact 20 lbs
# depth: exact 5.125 in
# depth: exact 5.75 in, width: exact 1.1 in, height: exact 8 in
# depth: exact 5.75 in, width: exact 11 in, height: exact 8 in
# depth: exact 5.9 in, height: exact 0.7 in, width: exact 2.3 in
# depth: exact 5.9 in, height: exact 35.8 in, width: exact 26.4 in, weight: exact 64.59 lbs
# depth: exact 500 mm
# depth: exact 55 mm
# depth: exact 6 in, height: exact 9.8 in, width: exact 14.3 in
# depth: exact 6 in, width: exact 11 in, height: exact 8 in
# depth: exact 60 cm
# depth: exact 7.5 cm
# depth: exact 750 mm
# depth: exact 8.86 in, height: exact 11.61 in, width: exact 31.3 in, weight: exact 22.71 lbs
# depth: exact 8.98 in, height: exact 12.64 in, width: exact 38.23 in, weight: exact 29.98 lbs
# depth: min 150 mm, depth: max 225 mm, length: exact 50 mm
# depth: min 3 in, depth: max 4 in
# depth: min 8.5 in, depth: max 13.5 in
# diameter: exact 0.03125 in, length: exact 1.5 in
# diameter: exact 0.035 in, length: exact 144 in
# diameter: exact 0.073 in
# diameter: exact 0.0938 in, length: exact 0.4375 in
# diameter: exact 0.095 in, length: exact 145 ft
# diameter: exact 0.104 in, length: exact 15 in
# diameter: exact 0.1094 in, length: exact 0.375 in
# diameter: exact 0.125 in, length: exact 100 ft
# diameter: exact 0.125 in, length: exact 32 in
# diameter: exact 0.125 in, length: min 1.25 in, length: max 2.25 in
# diameter: exact 0.13 in, thickness: exact 0.005 in
# diameter: exact 0.16 mm
# diameter: exact 0.1719 in, length: exact 2.625 in
# diameter: exact 0.1875 in
# diameter: exact 0.1875 in, length: exact 0.1563 in
# diameter: exact 0.1875 in, thickness: exact 0.032 in
# diameter: exact 0.2 in
# diameter: exact 0.22 in
# diameter: exact 0.2344 in, length: exact 3 in
# diameter: exact 0.25 in
# diameter: exact 0.25 in, length: exact 0.1875 in
# diameter: exact 0.25 in, length: exact 1500 mm
# diameter: exact 0.25 in, length: exact 2 in
# diameter: exact 0.25 in, length: exact 2.5 in
# diameter: exact 0.25 in, length: exact 20 ft
# diameter: exact 0.257 in
# diameter: exact 0.312 in
# diameter: exact 0.3125 in
# diameter: exact 0.3125 in, width: exact 2 in, length: exact 3.25 in
# diameter: exact 0.335 in
# diameter: exact 0.375 in
# diameter: exact 0.375 in, length: exact 2.5 in
# diameter: exact 0.375 in, length: exact 4 in
# diameter: exact 0.375 in, thickness: exact 0.375 in
# diameter: exact 0.41 in, length: exact 223 ft
# diameter: exact 0.42 mm, length: min 1.142 mm, length: max 3.5 mm
# diameter: exact 0.5 in
# diameter: exact 0.5 in, height: exact 0.65 in, length: exact 18 in
# diameter: exact 0.5 in, length: exact 0.375 in
# diameter: exact 0.5 in, length: exact 0.5 in
# diameter: exact 0.5 in, length: exact 1.96 in
# diameter: exact 0.5 in, length: exact 1524 mm
# diameter: exact 0.5 in, length: exact 6 in
# diameter: exact 0.5625 in
# diameter: exact 0.625 in
# diameter: exact 0.63 in
# diameter: exact 0.656 in, length: exact 1 in
# diameter: exact 0.75 in
# diameter: exact 0.75 in, length: exact 25 ft
# diameter: exact 0.75 in, length: min 17 mm, length: max 46 mm
# diameter: exact 0.75 in, length: min 2.25 in, length: max 5 in
# diameter: exact 0.75 mm
# diameter: exact 0.8 mm
# diameter: exact 0.8125 in, length: exact 10 ft
# diameter: exact 0.875 in
# diameter: exact 0.9 mm
# diameter: exact 1 in
# diameter: exact 1 in, length: exact 42 in
# diameter: exact 1 in, length: exact 96 in
# diameter: exact 1 in, thickness: exact 1 in
# diameter: exact 1 mm
# diameter: exact 1.0 in
# diameter: exact 1.0 mm
# diameter: exact 1.1 mm
# diameter: exact 1.125 in
# diameter: exact 1.125 in, width: exact 0.25 in
# diameter: exact 1.14 mm
# diameter: exact 1.15 in, weight: exact 0.16 lbs
# diameter: exact 1.18 mm
# diameter: exact 1.1875 in
# diameter: exact 1.25 in
# diameter: exact 1.25 in, height: exact 1.25 in
# diameter: exact 1.29 in, length: exact 10 ft
# diameter: exact 1.3 in
# diameter: exact 1.3 in, length: exact 12 in
# diameter: exact 1.3 mm
# diameter: exact 1.3125 in, length: min 12 in, length: max 72 in
# diameter: exact 1.375 in, thickness: exact 0.0625 in
# diameter: exact 1.4 in
# diameter: exact 1.5 in
# diameter: exact 1.5 in, length: exact 1.8 in, width: exact 1.8 in, height: exact 1.8 in
# diameter: exact 1.5 in, length: exact 15 in
# diameter: exact 1.5 in, length: exact 18.25 in
# diameter: exact 1.5 in, length: exact 2 in
# diameter: exact 1.5 in, length: exact 2.25 in
# diameter: exact 1.5 in, length: min 14 in, length: max 18 in
# diameter: exact 1.5 mm
# diameter: exact 1.5 mm, length: exact 20 cm
# diameter: exact 1.5 mm, length: exact 28 cm
# diameter: exact 1.55 mm
# diameter: exact 1.56 in
# diameter: exact 1.6 in
# diameter: exact 1.6 mm
# diameter: exact 1.625 in
# diameter: exact 1.67 in
# diameter: exact 1.75 in
# diameter: exact 1.75 mm
# diameter: exact 1.875 in
# diameter: exact 1.93 mm, width: exact 2.5 mm
# diameter: exact 1.93 mm, width: exact 3.2 mm
# diameter: exact 1.9375 in
# diameter: exact 10 ft
# diameter: exact 10 in
# diameter: exact 10 in, width: exact 3.5 in, length: exact 8.5 in, thickness: exact 0.375 in
# diameter: exact 10 mm
# diameter: exact 10.5 mm
# diameter: exact 100 mm
# diameter: exact 101 mm, height: exact 52 mm
# diameter: exact 11 mm
# diameter: exact 11.75 in, length: min 36 in, length: max 48 in
# diameter: exact 110 mm
# diameter: exact 110 mm, length: exact 3205 mm
# diameter: exact 110 mm, width: exact 12 mm
# diameter: exact 115 mm
# diameter: exact 115 mm, thickness: exact 6.0 mm
# diameter: exact 115 mm, width: exact 72 mm, height: exact 50 mm
# diameter: exact 12 in
# diameter: exact 12 mm
# diameter: exact 12 mm, length: exact 10 m
# diameter: exact 12 mm, length: exact 30 mm
# diameter: exact 12 mm, thickness: exact 1.5 mm
# diameter: exact 12.0 mm, length: exact 910 mm
# diameter: exact 12.188 in, thickness: exact 0.093 in
# diameter: exact 12.4 mm
# diameter: exact 122 mm
# diameter: exact 125 mm
# diameter: exact 128 mm
# diameter: exact 13 in
# diameter: exact 13 in, thickness: exact 0.25 in, width: exact 3 in, length: exact 5.375 in
# diameter: exact 13 in, width: exact 5.5 in, thickness: exact 0.5 in, length: exact 10.75 in
# diameter: exact 13 mm
# diameter: exact 13.25 in
# diameter: exact 13.5 in
# diameter: exact 13.5 mm, length: min 30 mm, length: max 36 mm
# diameter: exact 138.8 cm
# diameter: exact 14 in
# diameter: exact 14 mm
# diameter: exact 14.5 mm
# diameter: exact 140 mm
# diameter: exact 140.0 mm, length: exact 1040.0 mm, weight: exact 76.0 kg
# diameter: exact 15 in
# diameter: exact 15 mm
# diameter: exact 15.5 in
# diameter: exact 15.6 in
# diameter: exact 15.75 in, height: exact 30.125 in
# diameter: exact 150 mm
# diameter: exact 1500 mm
# diameter: exact 16 in
# diameter: exact 16 in, length: min 36 in, length: max 48 in
# diameter: exact 16 mm
# diameter: exact 16.4 mm
# diameter: exact 160 mm
# diameter: exact 17 in
# diameter: exact 17 mm
# diameter: exact 17 mm, weight: exact 530 g
# diameter: exact 17.2 in, height: exact 0.147 in, width: exact 0.04 in
# diameter: exact 18 in
# diameter: exact 18 in, height: exact 18.25 in
# diameter: exact 18 in, width: exact 7.5 in
# diameter: exact 18.5 mm, thickness: exact 9.5 mm
# diameter: exact 180 mm, length: exact 810 mm
# diameter: exact 185 mm
# diameter: exact 19 in
# diameter: exact 19 in, thickness: exact 0.625 in, width: exact 6.5 in, length: exact 10.63 in
# diameter: exact 19 mm
# diameter: exact 190 mm
# diameter: exact 2 in
# diameter: exact 2 in, length: exact 24 in
# diameter: exact 2 in, length: exact 40 m
# diameter: exact 2 mm
# diameter: exact 2.0 mm
# diameter: exact 2.25 in
# diameter: exact 2.35 mm
# diameter: exact 2.375 in
# diameter: exact 2.4 mm, weight: exact 35.8 kg
# diameter: exact 2.5 in
# diameter: exact 2.5 in, length: exact 24 in
# diameter: exact 2.5 in, length: exact 4 in
# diameter: exact 2.5 in, width: exact 44 mm
# diameter: exact 2.5 mm
# diameter: exact 2.52 mm, width: exact 3.2 mm
# diameter: exact 2.6 in, height: exact 7.41 in
# diameter: exact 2.604 in, width: exact 0.765 in, weight: exact 0.57 lbs
# diameter: exact 2.75 in
# diameter: exact 2.75 in, thickness: exact 0.0625 in
# diameter: exact 2.8 mm
# diameter: exact 20 in
# diameter: exact 20 in, width: exact 8.5 in
# diameter: exact 20 mm
# diameter: exact 20 mm, length: exact 50 m
# diameter: exact 200 mm
# diameter: exact 21 cm
# diameter: exact 22 in
# diameter: exact 22 in, height: exact 40 in
# diameter: exact 22 in, width: exact 10 in
# diameter: exact 22 mm
# diameter: exact 23 mm, length: exact 152 mm
# diameter: exact 230 mm
# diameter: exact 24 in
# diameter: exact 25 cm
# diameter: exact 25 mm
# diameter: exact 25 mm, height: exact 31 cm
# diameter: exact 250 mm
# diameter: exact 26 in
# diameter: exact 26 in, height: exact 42 in, weight: exact 145 lbs
# diameter: exact 27 cm
# diameter: exact 27 mm
# diameter: exact 28 cm
# diameter: exact 28 mm
# diameter: exact 29 cm
# diameter: exact 3 cm
# diameter: exact 3 in
# diameter: exact 3 mm
# diameter: exact 3 mm, length: exact 10 mm
# diameter: exact 3 mm, length: exact 100 mm
# diameter: exact 3 mm, length: exact 20 cm
# diameter: exact 3 mm, length: exact 330 mm
# diameter: exact 3 mm, length: exact 6.35 mm
# diameter: exact 3 mm, length: exact 8 mm
# diameter: exact 3.0 mm
# diameter: exact 3.0 mm, length: exact 16 mm
# diameter: exact 3.116 in
# diameter: exact 3.125 in
# diameter: exact 3.2 mm, length: exact 10 m
# diameter: exact 3.25 in, length: exact 5 in
# diameter: exact 3.25 in, thickness: exact 0.5 in
# diameter: exact 3.25 mm, length: exact 20 mm
# diameter: exact 3.3 in
# diameter: exact 3.3 in, height: exact 6.1 in
# diameter: exact 3.3 in, weight: exact 1.75 oz
# diameter: exact 3.3 mm
# diameter: exact 3.5 in
# diameter: exact 3.5 m
# diameter: exact 3.5 mm
# diameter: exact 3.75 in
# diameter: exact 3.75 mm
# diameter: exact 3.75 mm, length: exact 11.5 mm
# diameter: exact 3.75 mm, length: exact 15 mm
# diameter: exact 3.8 cm
# diameter: exact 30 cm
# diameter: exact 30 in, thickness: exact 0.75 in, width: exact 8 in, length: exact 15 in
# diameter: exact 30 mm
# diameter: exact 30 mm, length: exact 165 mm
# diameter: exact 30 mm, length: exact 180 mm, width: exact 810 mm
# diameter: exact 30 mm, length: exact 310 mm
# diameter: exact 30 mm, width: exact 31.5 mm
# diameter: exact 300 mm
# diameter: exact 32 in, height: min 17.126 in, height: max 19.291 in, length: exact 31.496 in, weight: exact 54.0133 lbs
# diameter: exact 32 in, width: exact 10.5 in
# diameter: exact 32 mm
# diameter: exact 32 mm, thickness: exact 1.5 mm
# diameter: exact 34 mm
# diameter: exact 340 mm
# diameter: exact 35 mm
# diameter: exact 37 mm
# diameter: exact 38 mm
# diameter: exact 38.1 cm
# diameter: exact 4 in
# diameter: exact 4 in, length: exact 10 ft
# diameter: exact 4 in, length: exact 20 ft
# diameter: exact 4 in, length: exact 24 in
# diameter: exact 4 in, length: min 36 in, length: max 48 in
# diameter: exact 4 in, thickness: exact 1 in
# diameter: exact 4 in, width: exact 55 mm
# diameter: exact 4 mm
# diameter: exact 4 mm, length: exact 12 mm
# diameter: exact 4 mm, length: exact 16 mm
# diameter: exact 4 mm, weight: exact 0.3 lbs
# diameter: exact 4.0 in
# diameter: exact 4.125 in
# diameter: exact 4.2 mm
# diameter: exact 4.25 in
# diameter: exact 4.25 in, depth: exact 6 in
# diameter: exact 4.3 in
# diameter: exact 4.5 in
# diameter: exact 4.5 in, thickness: exact 0.06 in
# diameter: exact 4.75 in
# diameter: exact 40 in
# diameter: exact 40 mm
# diameter: exact 40.3 mm
# diameter: exact 410 mm
# diameter: exact 42 mm
# diameter: exact 420 mm
# diameter: exact 44 in
# diameter: exact 45 mm, thickness: exact 10 mm
# diameter: exact 46.2 mm
# diameter: exact 47 cm
# diameter: exact 47 mm
# diameter: exact 48 in
# diameter: exact 48 in, height: exact 29 in, weight: exact 55 lbs
# diameter: exact 48 mm
# diameter: exact 49 cm, height: exact 14 cm
# diameter: exact 5 cm
# diameter: exact 5 ft, width: exact 2 ft
# diameter: exact 5 in
# diameter: exact 5 in, length: exact 13.11 in
# diameter: exact 5 in, thickness: exact 1.5 in
# diameter: exact 5 in, thickness: exact 6 mm, width: exact 22 mm
# diameter: exact 5 mm
# diameter: exact 5 mm, length: exact 100 mm, weight: exact 6 lbs
# diameter: exact 5 mm, length: exact 20 mm
# diameter: exact 5 mm, length: exact 330 mm
# diameter: exact 5.0 mm
# diameter: exact 5.2 mm
# diameter: exact 5.25 in
# diameter: exact 5.4 cm
# diameter: exact 5.5 in
# diameter: exact 5.52 mm
# diameter: exact 5.63 in
# diameter: exact 5.75 in
# diameter: exact 50 cm
# diameter: exact 50 in
# diameter: exact 50 mm
# diameter: exact 50 mm, thickness: exact 6 mm
# diameter: exact 50.8 mm
# diameter: exact 54 mm
# diameter: exact 55 cm
# diameter: exact 55 mm
# diameter: exact 58 cm
# diameter: exact 58 mm
# diameter: exact 6 in
# diameter: exact 6 in, length: exact 12 in
# diameter: exact 6 in, length: exact 6 in
# diameter: exact 6 in, thickness: exact 0.375 in
# diameter: exact 6 in, width: exact 6 in
# diameter: exact 6 mm
# diameter: exact 6 mm, length: exact 100 mm
# diameter: exact 6 mm, length: exact 6.35 mm
# diameter: exact 6 mm, length: exact 630 mm
# diameter: exact 6 mm, weight: exact 20 lbs
# diameter: exact 6.25 in
# diameter: exact 6.35 in
# diameter: exact 6.35 mm
# diameter: exact 6.5 in
# diameter: exact 6.5 mm, length: exact 2300 mm
# diameter: exact 6.58 in
# diameter: exact 60 in, thickness: exact 1.25 in
# diameter: exact 60 mm
# diameter: exact 62 cm
# diameter: exact 62 mm
# diameter: exact 63 mm
# diameter: exact 65 mm, length: exact 158 mm
# diameter: exact 670 mm
# diameter: exact 7 cm
# diameter: exact 7 in
# diameter: exact 7 mm, length: exact 150 mm
# diameter: exact 7 mm, thickness: exact 4 mm
# diameter: exact 7.25 in
# diameter: exact 7.5 in
# diameter: exact 7.75 in
# diameter: exact 7.75 in, length: exact 9.625 in
# diameter: exact 70 mm
# diameter: exact 72 mm
# diameter: exact 72 mm, height: exact 15 mm, weight: exact 36 g
# diameter: exact 72 mm, height: exact 15 mm, weight: exact 42 g
# diameter: exact 72 mm, height: exact 19 mm, weight: exact 42 g
# diameter: exact 72 mm, height: exact 22 mm, weight: exact 63 g
# diameter: exact 72.3 in, length: exact 103.2 in
# diameter: exact 75 mm
# diameter: exact 750 mm, width: exact 150 mm
# diameter: exact 8 in
# diameter: exact 8 in, thickness: exact 0.375 in, width: exact 3 in, length: exact 5.375 in
# diameter: exact 8 in, thickness: exact 0.75 in
# diameter: exact 8 mm
# diameter: exact 8 mm, length: exact 1.25 mm
# diameter: exact 8 mm, length: exact 5 mm
# diameter: exact 8.5 in
# diameter: exact 80 mm
# diameter: exact 85 mm, width: exact 210 mm, thickness: exact 52 mm
# diameter: exact 9 in
# diameter: exact 9 in, height: exact 3.543 in
# diameter: exact 9 in, width: exact 3.5 in
# diameter: exact 9 in, width: exact 8 in
# diameter: exact 9 in, width: exact 9.25 in, height: exact 2.14 in
# diameter: exact 9 mm
# diameter: exact 9.25 in, length: min 36 in, length: max 48 in
# diameter: exact 9.5 in
# diameter: exact 92 in
# diameter: exact 98 mm
# diameter: max 0.5 in, diameter: min 0.375 in
# diameter: max 1 in, diameter: min 0.75 in
# diameter: max 1.063 in, diameter: min 0.938 in
# diameter: max 1.375 in, diameter: min 1.25 in, length: min 36 in, length: max 48 in
# diameter: max 1.6 mm, diameter: min 0.045 mm
# diameter: max 10 in, diameter: min 9 in
# diameter: max 10 mm, diameter: min 5 mm
# diameter: max 10.25 in, diameter: min 9.125 in, height: exact 7.5 in
# diameter: max 10.313 in, diameter: min 9.313 in, thickness: exact 0.5 in
# diameter: max 12 in, diameter: min 5 in
# diameter: max 130 mm, diameter: min 120 mm
# diameter: max 133 mm, diameter: min 88 mm
# diameter: max 18 mm, diameter: min 10 mm, length: exact 13 mm
# diameter: max 24 in, diameter: min 1 in
# diameter: max 24 in, diameter: min 18 in
# diameter: max 24 in, diameter: min 5 in
# diameter: max 30 mm, diameter: min 6 mm
# diameter: max 400 in, diameter: min 88 in
# diameter: max 42 mm, diameter: min 16 mm
# diameter: max 5 mm, diameter: min 3.5 mm, length: exact 100 mm
# diameter: max 5.812 in, diameter: min 4.813 in, thickness: exact 0.5 in
# diameter: max 55 mm, diameter: min 32.3 mm, length: exact 146 mm
# diameter: max 7 mm, diameter: min 4 mm
# diameter: max 8 in, diameter: min 5.5 in, thickness: exact 2 in
# diameter: max 9.843 in, diameter: min 0.276 in, height: exact 11.417 in, length: exact 11.811 in
# diameter: min 0.125 in, diameter: max 0.75 in
# diameter: min 0.125 in, diameter: max 4 in
# diameter: min 0.1875 in, diameter: max 0.5 in
# diameter: min 0.25 in, diameter: max 0.375 in
# diameter: min 0.25 in, diameter: max 0.5 in
# diameter: min 0.25 in, diameter: max 0.75 in
# diameter: min 0.25 in, diameter: max 1 in
# diameter: min 0.25 in, diameter: max 3.375 in
# diameter: min 0.34 mm, diameter: max 0.799 mm
# diameter: min 0.375 in, diameter: max 0.5 in
# diameter: min 0.375 in, diameter: max 24 in
# diameter: min 0.5 in, diameter: max 0.625 in
# diameter: min 0.5 in, diameter: max 1 in
# diameter: min 0.5 in, diameter: max 4 in
# diameter: min 0.5 in, diameter: max 6 in
# diameter: min 0.6 mm, diameter: max 100 mm
# diameter: min 0.68 mm, diameter: max 0.9 mm, length: exact 25.4 mm, height: min 4.2 mm, height: max 5.2 mm
# diameter: min 0.75 in, diameter: max 1 in
# diameter: min 0.75 in, diameter: max 5 in, length: exact 2.25 in
# diameter: min 1 in, diameter: max 1.5 in
# diameter: min 1 in, diameter: max 10 in
# diameter: min 1 in, diameter: max 12 in
# diameter: min 1 in, diameter: max 2 in
# diameter: min 1 in, diameter: max 2 in, length: min 180 mm, length: max 270 mm
# diameter: min 1 in, diameter: max 20 in
# diameter: min 1 in, diameter: max 3 in
# diameter: min 1 in, diameter: max 4 in
# diameter: min 1 in, diameter: max 5 in
# diameter: min 1 in, diameter: max 8 in
# diameter: min 1 mm, diameter: max 29.5 mm
# diameter: min 1 mm, diameter: max 60 mm, length: exact 1500 mm
# diameter: min 1.0 in, diameter: max 1.5 in
# diameter: min 1.0 mm, diameter: max 2.0 mm
# diameter: min 1.049 in, diameter: max 1.315 in, length: exact 10 ft
# diameter: min 1.05 in, diameter: max 7.01 in
# diameter: min 1.12 in, diameter: max 2.09 in
# diameter: min 1.25 in, diameter: max 1.5 in
# diameter: min 1.25 in, diameter: max 2.5 in
# diameter: min 1.3125 in, diameter: max 2.04 in, height: min 1.0 in, height: max 2.04 in
# diameter: min 1.335 in, diameter: max 1.66 in, length: exact 13 in
# diameter: min 1.5 in, diameter: max 12 in, length: min 2 in, length: max 20 in
# diameter: min 1.5 in, diameter: max 2 in, length: exact 15 ft
# diameter: min 1.5 in, diameter: max 2.5 in, length: exact 5 ft
# diameter: min 1.75 in, diameter: max 1.875 in
# diameter: min 1.875 mm, diameter: max 47.6 mm
# diameter: min 10 in, diameter: max 13 in
# diameter: min 10 in, diameter: max 14 in
# diameter: min 10 in, diameter: max 16 in, thickness: min 0.5 in, thickness: max 8.5 in, width: min 5.5 in, width: max 7.875 in
# diameter: min 10 in, diameter: max 24 in
# diameter: min 10 mm, diameter: max 20 mm
# diameter: min 10 mm, diameter: max 30 mm, thickness: exact 9 mm
# diameter: min 10 mm, diameter: max 60 mm
# diameter: min 100 mm, diameter: max 120 mm
# diameter: min 1000 mm, diameter: max 3000 mm
# diameter: min 105 mm
# diameter: min 105 mm, diameter: max 230 mm
# diameter: min 11 mm, diameter: max 29 mm
# diameter: min 115 mm, diameter: max 450 mm
# diameter: min 12 mm, diameter: max 20 mm
# diameter: min 120 mm, diameter: max 210 mm, thickness: exact 54 mm
# diameter: min 125 mm, diameter: max 350 mm
# diameter: min 13 mm, diameter: max 161 mm
# diameter: min 13 mm, diameter: max 28 mm, thickness: min 11 mm, thickness: max 21 mm, length: min 13 mm, length: max 24 mm
# diameter: min 14 in, diameter: max 19 in
# diameter: min 14 mm, diameter: max 16 mm
# diameter: min 14 mm, diameter: max 22 mm, height: exact 13 mm
# diameter: min 15 in, diameter: max 19 in
# diameter: min 15 in, diameter: max 26 in
# diameter: min 15 mm, diameter: max 150 mm
# diameter: min 15 mm, diameter: max 20 mm
# diameter: min 15 mm, diameter: max 200 mm
# diameter: min 15 mm, diameter: max 22 mm
# diameter: min 15 mm, diameter: max 600 mm, thickness: min 2 mm, thickness: max 100 mm
# diameter: min 15 mm, diameter: max 80 mm
# diameter: min 15.375 in, diameter: max 16.125 in, length: min 3 ft, length: max 48 ft
# diameter: min 16 mm, diameter: max 110 mm
# diameter: min 160 mm, diameter: max 220 mm, width: exact 28 mm
# diameter: min 17 in, diameter: max 18 in
# diameter: min 17 in, diameter: max 20 in
# diameter: min 17 in, diameter: max 22 in
# diameter: min 17 in, diameter: max 22 in, width: exact 9.5 in
# diameter: min 17 mm, diameter: max 30 mm, width: exact 14 mm
# diameter: min 18 cm, diameter: max 50 cm
# diameter: min 18 in, diameter: max 18.5 in
# diameter: min 18 in, diameter: max 30 in
# diameter: min 18 mm, diameter: max 25 mm
# diameter: min 18 mm, diameter: max 43 mm, length: exact 3600 mm
# diameter: min 18 mm, diameter: max 50 mm
# diameter: min 19 mm, diameter: max 25 mm
# diameter: min 19 mm, diameter: max 44 mm
# diameter: min 2 in, diameter: max 12 in
# diameter: min 2 in, diameter: max 16 in
# diameter: min 2 mm, diameter: max 180 mm, length: exact 810 mm
# diameter: min 2 mm, diameter: max 5 mm
# diameter: min 2.0 mm, diameter: max 18 mm
# diameter: min 2.0 mm, diameter: max 4.2 mm, length: min 11.5 mm, length: max 18 mm
# diameter: min 2.375 in, diameter: max 2.75 in
# diameter: min 2.5 in, diameter: max 4 in
# diameter: min 2.5 in, diameter: max 5.0 in
# diameter: min 20 in, diameter: max 22 in
# diameter: min 20 mm, diameter: max 110 mm
# diameter: min 20 mm, diameter: max 120 mm
# diameter: min 21 mm, diameter: max 25.5 mm
# diameter: min 21.89 mm, diameter: max 27.13 mm, width: exact 2.62 mm
# diameter: min 22 in, diameter: max 23.8 in
# diameter: min 22 in, diameter: max 23.9 in
# diameter: min 22 mm, diameter: max 100 mm, height: min 350 mm, height: max 650 mm, weight: exact 33 kg
# diameter: min 230 mm, diameter: max 350 mm
# diameter: min 24 cm, diameter: max 40 cm
# diameter: min 25 mm, diameter: max 52 mm, width: exact 15 mm
# diameter: min 25 mm, diameter: max 62 mm, thickness: exact 24 mm
# diameter: min 28 mm, diameter: max 40 mm
# diameter: min 28 mm, diameter: max 68 mm, thickness: exact 18 mm
# diameter: min 3 in, diameter: max 10 in
# diameter: min 3 in, diameter: max 20 in
# diameter: min 3 in, diameter: max 24 in
# diameter: min 3 in, diameter: max 4 in
# diameter: min 3 in, diameter: max 6 in
# diameter: min 3 m, diameter: max 20 m
# diameter: min 3 mm, diameter: max 4 in
# diameter: min 3 mm, diameter: max 6 mm
# diameter: min 3 mm, diameter: max 6 mm, length: exact 6.35 mm
# diameter: min 3.1 mm, diameter: max 76.2 mm
# diameter: min 3.5 in, diameter: max 4.5 in
# diameter: min 3.5 mm, diameter: max 4 mm
# diameter: min 3.75 mm, diameter: max 17 mm, length: min 11.5 mm, length: max 17 mm
# diameter: min 3.8 in, diameter: max 7.8 in, length: exact 12 in
# diameter: min 30 in, diameter: max 100 in
# diameter: min 30 mm, diameter: max 34 mm, length: exact 25 mm
# diameter: min 305 mm, diameter: max 4400 mm, thickness: min 16.3 mm, thickness: max 128.6 mm
# diameter: min 32 mm, diameter: max 160 mm
# diameter: min 32 mm, diameter: max 59 mm, height: min 66 mm, height: max 120 mm
# diameter: min 320 mm, diameter: max 580 mm, thickness: exact 155 mm
# diameter: min 35 mm, diameter: max 58 mm
# diameter: min 4 in, diameter: max 10 in
# diameter: min 4 in, diameter: max 6.5 in
# diameter: min 4 in, diameter: max 8 in
# diameter: min 4 mm, diameter: max 6 mm
# diameter: min 4 mm, diameter: max 7 mm
# diameter: min 4 mm, diameter: max 9 mm
# diameter: min 4.0 in, diameter: max 30 in
# diameter: min 4.2 mm, diameter: max 18 mm, length: min 10 mm, length: max 18 mm
# diameter: min 4.5 in, diameter: max 30 in
# diameter: min 40 mm, diameter: max 110 mm
# diameter: min 40 mm, diameter: max 185 mm
# diameter: min 40 mm, diameter: max 50 mm
# diameter: min 40 mm, diameter: max 65 mm
# diameter: min 40 mm, diameter: max 80 mm
# diameter: min 42 in, diameter: max 60 in
# diameter: min 45 mm, diameter: max 100 mm, thickness: exact 36 mm
# diameter: min 49 mm, diameter: max 183.5 mm, height: min 34 mm, height: max 132 mm
# diameter: min 5 in, diameter: max 15.5 in
# diameter: min 5 in, diameter: max 24 in
# diameter: min 5 mm, diameter: max 150 mm, length: exact 560 mm
# diameter: min 5 mm, diameter: max 24 mm
# diameter: min 5 mm, diameter: max 6 mm
# diameter: min 5 mm, diameter: max 6 mm, length: exact 50 mm
# diameter: min 5 mm, diameter: max 6 mm, length: max 100 mm, length: min 50 mm
# diameter: min 50 mm, diameter: max 110 mm
# diameter: min 50 mm, diameter: max 600 mm
# diameter: min 55 cm, diameter: max 56 cm
# diameter: min 55 mm, diameter: max 100 mm, height: exact 21 mm
# diameter: min 55 mm, diameter: max 120 mm, thickness: exact 43 mm
# diameter: min 59 cm, diameter: max 61 cm
# diameter: min 6 in
# diameter: min 6 in, diameter: max 24 in
# diameter: min 6 in, diameter: max 8 in
# diameter: min 6 mm, diameter: max 8 mm
# diameter: min 60 mm, diameter: max 130 mm, thickness: exact 46 mm
# diameter: min 63 mm, diameter: max 160 mm
# diameter: min 660 mm, diameter: max 680 mm, weight: min 260 g, weight: max 280 g
# diameter: min 7 in, diameter: max 15.5 in
# diameter: min 7 in, diameter: max 24 in
# diameter: min 7 in, diameter: max 32 in
# diameter: min 7 mm, diameter: max 11 mm
# diameter: min 7.5 in, diameter: max 7.75 in, width: exact 0.125 in
# diameter: min 70 mm, diameter: max 112 mm, length: exact 142 mm
# diameter: min 70 mm, diameter: max 150 mm, thickness: exact 51 mm
# diameter: min 70 mm, diameter: max 250 mm
# diameter: min 75 mm, diameter: max 130 mm
# diameter: min 75 mm, diameter: max 160 mm, thickness: exact 55 mm
# diameter: min 8 in, diameter: max 65 mm
# diameter: min 8 mm, diameter: max 10 mm
# diameter: min 8.5 in, diameter: max 22 in
# diameter: min 80 mm, diameter: max 120 mm
# diameter: min 80 mm, diameter: max 120 mm, thickness: exact 55 mm
# diameter: min 9 in, diameter: max 15.5 in
# diameter: min 90 mm, diameter: max 125 mm, width: exact 18 mm
# height: exact 0.00635 m, width: exact 0.004 m, length: exact 0.0803 m
# height: exact 0.5 in, width: exact 19.9 in
# height: exact 0.5 in, width: exact 3.4375 in, length: exact 8 ft
# height: exact 1 in, width: exact 2.5 in, depth: exact 10 in
# height: exact 1 in, width: exact 60 in
# height: exact 1.0625 in
# height: exact 1.1 in, width: exact 1.7 in, depth: exact 1 in
# height: exact 1.1 in, width: exact 4.5 in, depth: exact 2.5 in
# height: exact 1.12 in, width: exact 4 in, depth: exact 4 in
# height: exact 1.25 in
# height: exact 1.25 in, depth: exact 30 in, width: exact 30 in
# height: exact 1.25 in, width: exact 2 in, depth: exact 15 in
# height: exact 1.5 in
# height: exact 1.5 in, width: exact 2 in, depth: exact 6 in
# height: exact 1.5 in, width: exact 3 in, depth: exact 6 in
# height: exact 1.5 in, width: exact 3.8 in, depth: exact 1.8 in
# height: exact 1.5 in, width: exact 7.5 in, depth: exact 6.5 in
# height: exact 10 ft
# height: exact 10 in
# height: exact 10 in, volume: exact 4.5 l
# height: exact 10 in, width: exact 1.5 in
# height: exact 10 in, width: exact 10.5 in, depth: exact 10 in
# height: exact 10 in, width: exact 18 in, depth: exact 4 in
# height: exact 10.35 in, length: exact 6.84 in, width: exact 10.37 in
# height: exact 1000 mm, diameter: exact 1284 mm
# height: exact 108 in
# height: exact 11 in
# height: exact 11 in, width: exact 5 in, weight: exact 2 oz
# height: exact 11 in, width: exact 5.5 in, depth: exact 3 in
# height: exact 11 in, width: exact 8 in
# height: exact 11.14 m
# height: exact 11.5 in
# height: exact 11.88 in, width: exact 8.19 in, depth: exact 10.12 in
# height: exact 12 ft
# height: exact 12 in
# height: exact 12 in, length: exact 13 in
# height: exact 12 in, width: exact 9 in, depth: exact 2 in
# height: exact 12 m
# height: exact 12.5 in, width: exact 5 in
# height: exact 12.6 in, width: exact 8.8 in, depth: exact 10.1 in
# height: exact 12.68 in, width: exact 4.56 in, depth: exact 7.92 in
# height: exact 13 cm, width: exact 4 cm
# height: exact 13.5 in, width: exact 10.5 in, depth: exact 5 in
# height: exact 13.5 in, width: exact 10.5 in, depth: exact 5 in, weight: exact 2.92 lbs
# height: exact 13.5 in, width: exact 9 in, depth: exact 4 in
# height: exact 135.1 cm, length: exact 255.7 cm, width: exact 81.7 cm
# height: exact 1397 mm
# height: exact 14.5 in, width: exact 3.52 in, depth: exact 2.31 in
# height: exact 14.88 in, width: exact 10.19 in, depth: exact 15.88 in
# height: exact 145.7 cm
# height: exact 15 cm
# height: exact 15 in, width: exact 11 in, depth: exact 4 in
# height: exact 15 in, width: exact 12 in
# height: exact 15 in, width: exact 21.75 in, depth: exact 13.5 in
# height: exact 15.5 in, width: exact 17.5 in, depth: exact 10 in, weight: exact 11.88 lbs
# height: exact 150 mm
# height: exact 1500 mm, width: exact 300 mm, depth: exact 300 mm
# height: exact 151 cm, width: exact 13 cm
# height: exact 16 ft
# height: exact 16 in, width: exact 10.87 in, depth: exact 4 in
# height: exact 16 in, width: exact 42 in, depth: exact 21 in
# height: exact 16.25 in, width: exact 5.5 in, depth: exact 4.25 in, weight: exact 5.5 lbs
# height: exact 16.5 in, width: exact 11.6 in, depth: exact 5.1 in
# height: exact 16.75 in, width: exact 51.25 in, depth: exact 33.75 in
# height: exact 16.8125 ft, weight: exact 1716 lbs
# height: exact 16.9 in, length: exact 5.5 in, width: exact 9.8 in, weight: exact 0.7 lbs
# height: exact 17 in
# height: exact 17 in, depth: exact 20 in
# height: exact 17 in, width: exact 12 in, depth: exact 8 in
# height: exact 17.7 in, width: exact 6.5 in, length: exact 11.7 in
# height: exact 18 cm, width: exact 150 cm, depth: exact 100 cm
# height: exact 18 in, width: exact 8 in, length: exact 12 in
# height: exact 18.03 in, width: exact 41.34 in, depth: exact 29.29 in, weight: exact 153.2 lbs
# height: exact 18.5 in, length: exact 15 in, width: exact 6.5 in
# height: exact 19 in, width: exact 3 in, length: exact 11 in
# height: exact 19.1875 in, depth: exact 15.875 in, width: exact 16.5625 in
# height: exact 1991 cm, width: exact 750 cm, depth: exact 1200 cm
# height: exact 2 ft
# height: exact 2 in
# height: exact 2 in, width: exact 12 mm
# height: exact 2 in, width: exact 2 in
# height: exact 2 in, width: exact 2.5 in, depth: exact 15 in
# height: exact 2 in, width: exact 3.55 in, weight: exact 0.21 lbs
# height: exact 2.1 m, width: exact 1 m, depth: exact 2 m
# height: exact 2.1 m, width: exact 2.6 m, length: exact 1.0 m
# height: exact 2.125 in
# height: exact 2.25 in, width: exact 9.53125 in, depth: exact 4.875 in
# height: exact 2.3 ft
# height: exact 2.4 in, length: exact 7.2 in
# height: exact 2.5 in
# height: exact 2.5 in, diameter: exact 1 in
# height: exact 2.5 in, width: exact 2.5 in, depth: exact 15 in
# height: exact 2.5 in, width: exact 3 in, depth: exact 15 in
# height: exact 2.68 in, width: exact 3.15 in, depth: exact 4.41 in
# height: exact 2.75 in, width: exact 2 in, depth: exact 0.5 in
# height: exact 2.8 in, width: exact 2.4 in, length: exact 5 in
# height: exact 20 cm
# height: exact 20 cm, width: exact 11 cm, volume: exact 1500 ml
# height: exact 20 ft
# height: exact 20 in
# height: exact 20.5 in, width: exact 15 in, depth: exact 17.5 in
# height: exact 20.5 in, width: exact 15 in, depth: exact 17.5 in, weight: exact 37 lbs
# height: exact 20.7 in, weight: exact 190 lbs
# height: exact 20.7 in, width: exact 16.9 in, weight: exact 190 lbs
# height: exact 21.1 in, width: exact 6.1 in, depth: exact 3.1 in
# height: exact 21.25 in, width: exact 41.5 in, depth: exact 41.5 in
# height: exact 21.5 in, length: exact 11.8 in, width: exact 8.3 in
# height: exact 21.69 in, length: exact 14.06 in, weight: exact 26.5 lbs
# height: exact 21.88 in, depth: exact 12.88 in, width: exact 16.88 in
# height: exact 23 in, width: exact 14.5 in, depth: exact 9 in
# height: exact 23 in, width: exact 22 in, depth: exact 24 in
# height: exact 23.5 in, width: exact 17.25 in, depth: exact 20 in
# height: exact 24 ft
# height: exact 24 in, width: exact 35 in, weight: exact 390 lbs
# height: exact 25 in
# height: exact 26 in, width: exact 19 in, depth: exact 13 in
# height: exact 26 in, width: exact 19 in, depth: exact 13 in, weight: exact 15.43 lbs
# height: exact 27 in
# height: exact 27 in, width: exact 10 in, length: exact 10 in
# height: exact 27 in, width: exact 18.5 in, depth: exact 11.5 in
# height: exact 28 in, width: exact 36 in, depth: exact 36 in, weight: exact 50 lbs
# height: exact 28.44 in, width: exact 36 in, depth: exact 36 in
# height: exact 29 cm, width: exact 23.5 cm, depth: exact 7 cm
# height: exact 29 in, length: exact 21 in, width: exact 13 in
# height: exact 29 in, width: exact 21 in, depth: exact 13 in
# height: exact 29.5 in, length: exact 12.6 in, width: exact 20.1 in
# height: exact 3 ft
# height: exact 3 in
# height: exact 3 in, width: exact 18.5 in, depth: exact 16 in
# height: exact 3.0 m
# height: exact 3.06 m, width: exact 9.2 m, depth: exact 2.12 m
# height: exact 3.0625 in, length: exact 2.25 in, width: exact 0.73 in
# height: exact 3.125 in
# height: exact 3.18 in, width: exact 7.6 in, depth: exact 14.7 in, weight: exact 322.1 g
# height: exact 3.4 in, width: exact 4.2 in, depth: exact 6.0 in, weight: exact 1.5 lbs
# height: exact 3.5 in, width: exact 2.25 in
# height: exact 3.5 in, width: exact 3.75 in, length: exact 5.25 in, weight: exact 0.2 lbs
# height: exact 3.6 m
# height: exact 3.75 in
# height: exact 3.75 in, diameter: exact 2.25 in
# height: exact 30 in
# height: exact 30 in, width: exact 30 in
# height: exact 30 in, width: exact 36 in, depth: exact 18 in
# height: exact 300 mm, depth: exact 700 mm, width: exact 1350 mm
# height: exact 31.8 in, width: exact 33 in, depth: exact 17 in, weight: exact 6 lbs
# height: exact 33.25 in, width: exact 23 in, depth: exact 18.6 in, weight: exact 29.8 lbs
# height: exact 33.5 in, width: exact 23.63 in, depth: exact 23.5 in
# height: exact 34 in, width: exact 32 in, depth: exact 61.25 in
# height: exact 34 in, width: exact 32 in, depth: exact 76 in
# height: exact 35 in
# height: exact 35 in, width: exact 56 in, depth: exact 32 in
# height: exact 350 mm
# height: exact 37.25 in, width: exact 24.75 in, depth: exact 22 in, weight: exact 71 lbs
# height: exact 38 in
# height: exact 38.75 in, width: exact 56.5 in, depth: exact 24 in, length: exact 52 in
# height: exact 39 in
# height: exact 39 mm
# height: exact 396 in, width: exact 305 in, depth: exact 440 in
# height: exact 4 ft
# height: exact 4 ft, length: exact 8 ft, depth: exact 0.06 in
# height: exact 4 ft, length: exact 8 ft, thickness: exact 0.04 in
# height: exact 4 in
# height: exact 4 in, length: exact 6 in, width: exact 4 in
# height: exact 4.125 in
# height: exact 4.5 in
# height: exact 4.8 in
# height: exact 40 mm, thickness: exact 1.5 mm, width: exact 490 mm, length: exact 1110 mm, weight: exact 900 g
# height: exact 40.125 in, width: exact 23 in, depth: exact 36 in
# height: exact 40.25 in, width: exact 20.5 in, depth: exact 30 in
# height: exact 41 cm, weight: exact 1.5 kg
# height: exact 41 in
# height: exact 41.5 in, width: exact 6.25 in, depth: exact 4.25 in
# height: exact 42 in, depth: exact 40 in, width: exact 34 in, weight: exact 350 lbs
# height: exact 44 cm
# height: exact 440 mm, width: exact 300 mm, length: exact 450 mm
# height: exact 45 m
# height: exact 45.5 in, width: exact 32 in, depth: exact 22 in
# height: exact 450 mm
# height: exact 450 mm, width: exact 1180 mm
# height: exact 46 cm, length: exact 175.5 cm, width: exact 85 cm
# height: exact 47.5 in, width: exact 25.25 in, depth: exact 30.75 in
# height: exact 5 cm
# height: exact 5 ft
# height: exact 5 in, width: exact 1.5 in, depth: exact 2.5 in
# height: exact 5 mm
# height: exact 5.5 in, diameter: exact 6 in
# height: exact 5.5 in, width: exact 0.5625 in
# height: exact 5.5 in, width: exact 4.5 in
# height: exact 5.5 in, width: exact 8.25 in, depth: exact 5.5 in
# height: exact 5.7 in
# height: exact 5.75 in, diameter: exact 5 in
# height: exact 5.75 in, width: exact 4 in
# height: exact 5.75 in, width: exact 6 in, depth: exact 6 in
# height: exact 50 in
# height: exact 51 in, width: exact 15 in
# height: exact 53 in
# height: exact 54 in, width: exact 28 in, depth: exact 19 in
# height: exact 54.75 in, width: exact 13.5 in, depth: exact 14.25 in, weight: exact 19 lbs
# height: exact 55.88 cm, diameter: exact 50.8 cm
# height: exact 57 in, width: exact 24 in, depth: exact 48 in, length: exact 48 in
# height: exact 58 cm, diameter: exact 32 cm
# height: exact 58 cm, width: exact 32 cm, depth: exact 21 cm
# height: exact 59 in, depth: exact 1.5 in, width: exact 24 in
# height: exact 6 ft
# height: exact 6 in
# height: exact 6 in, diameter: exact 3.25 in
# height: exact 6 in, width: exact 36 in, length: exact 80 in
# height: exact 6 in, width: exact 4.5 in, length: exact 4.5 in
# height: exact 6 in, width: exact 42 in, length: exact 76 in
# height: exact 6 in, width: exact 6 in
# height: exact 6 in, width: exact 8 in
# height: exact 6 m, width: exact 2.5 m, depth: exact 1.25 m
# height: exact 6.1 in, width: exact 8.3 in, depth: exact 2.6 in, weight: exact 0.57 lbs
# height: exact 6.25 in
# height: exact 6.4 in, width: exact 17.5 in, depth: exact 8 in
# height: exact 6.5 in, diameter: exact 3.5 in
# height: exact 6.5 in, width: exact 8 in
# height: exact 6.7 in, width: exact 4.9 in, depth: exact 0.8 in
# height: exact 60 cm
# height: exact 60 cm, width: exact 80 cm, depth: exact 9.5 cm
# height: exact 60 in, width: exact 36 in
# height: exact 64.8 in, width: exact 38 in, depth: exact 37.25 in
# height: exact 68 in, diameter: exact 10 in
# height: exact 69 mm, width: exact 70 mm, depth: exact 40 mm
# height: exact 7 in
# height: exact 7 in, diameter: exact 8 in
# height: exact 7 in, width: exact 10 in
# height: exact 7 in, width: exact 7 in, length: exact 1.75 in
# height: exact 7.0 in, width: exact 0.8 in, depth: exact 10.0 in
# height: exact 7.5 m
# height: exact 7.875 in
# height: exact 7.9 m
# height: exact 70 in, width: exact 24 in
# height: exact 70 mm
# height: exact 74 cm, width: exact 65.5 cm, depth: exact 57 cm
# height: exact 75 mm
# height: exact 78 cm, width: exact 153 cm, depth: exact 70 cm
# height: exact 78.94 in, width: exact 25.47 in, depth: exact 43.3 in, weight: exact 1459.66 kg
# height: exact 79 cm
# height: exact 79 in, weight: exact 5.2 lbs
# height: exact 8 cm, width: exact 87 cm, depth: exact 2 cm
# height: exact 8 ft
# height: exact 8 in
# height: exact 8 in, length: exact 16 in
# height: exact 8 in, width: exact 12.25 in, length: exact 12.25 in
# height: exact 8 in, width: exact 14 in, length: exact 24 in
# height: exact 8 in, width: exact 42 in, length: exact 78 in, weight: exact 35 lbs
# height: exact 8 in, width: exact 7 in, depth: exact 2 in
# height: exact 8.2 ft
# height: exact 800 mm, weight: exact 45 kg
# height: exact 84 in
# height: exact 85 cm, width: exact 24 cm, depth: exact 78 cm
# height: exact 85 mm, weight: exact 6000 g
# height: exact 9 cm
# height: exact 9 in, depth: exact 4 in
# height: exact 9 in, width: exact 4 in, length: exact 20 ft
# height: exact 9.13 in, width: exact 1.56 in
# height: exact 90 cm
# height: max 16 in, height: min 13 in
# height: max 35 in, height: min 16 in, width: exact 19 in
# height: max 39 in, height: min 20 in, width: exact 34.75 in, depth: exact 37 in
# height: max 54.7 in, height: min 14 in, length: exact 26.7 in, weight: exact 4.4 lbs
# height: max 6 in, height: min 1.5 in, diameter: exact 3.75 in
# height: min 1.75 in, height: max 2.75 in
# height: min 12 ft, height: max 24 ft
# height: min 13 cm, height: max 36 cm, width: exact 25 cm
# height: min 14.5 in, height: max 20 in
# height: min 16 in, height: max 19.5 in
# height: min 18 in, height: max 30 in, width: exact 15.5 in, depth: exact 15.5 in
# height: min 18 in, height: max 30 in, width: exact 17 in
# height: min 19 mm, height: max 29.5 mm
# height: min 2 ft, height: max 3 ft
# height: min 2 in, height: max 3 in
# height: min 2.5 in, height: max 5 in, diameter: min 1.25 in, diameter: max 1.875 in
# height: min 2.57 m, height: max 6.35 m
# height: min 20 in, height: max 30 in, diameter: min 32 cm, diameter: max 34 cm
# height: min 21 mm, height: max 100 mm, diameter: min 6 mm, diameter: max 100 mm, weight: min 0.1 kg, weight: max 5.8 kg
# height: min 23 in, height: max 33 in, depth: exact 4 in
# height: min 25 in, height: max 33 in
# height: min 3000 mm, height: max 5000 mm
# height: min 31 in, height: max 37 in, depth: exact 36 in, width: exact 18 in
# height: min 34 ft, height: max 63 ft
# height: min 36 in, height: max 72 in
# height: min 4.1 ft, height: max 6.1 ft
# height: min 40 cm, height: max 48 cm, width: min 40 cm, width: max 48 cm, length: exact 55 cm
# height: min 55 cm, height: max 59 cm
# height: min 6 ft, height: max 10 ft
# height: min 6.25 in, height: max 16.75 in, width: exact 16.75 in, depth: exact 2.75 in
# height: min 7 ft, height: max 8 ft, width: exact 27 in, weight: min 72 lbs, weight: max 77 lbs
# height: min 800 mm, height: max 1050 mm, length: exact 2100 mm, width: exact 475 mm
# length: exact 0.1 in
# length: exact 0.25 m
# length: exact 0.31 in, width: exact 0.31 in, height: exact 0.25 in, weight: exact 0.75 lbs
# length: exact 0.3125 in
# length: exact 0.5 ft
# length: exact 0.5 in, width: exact 0.5 in, height: exact 1 in
# length: exact 0.5 m
# length: exact 0.75 in
# length: exact 0.75 in, width: exact 0.5 in
# length: exact 0.875 in, width: exact 0.375 in
# length: exact 0.95 m, width: exact 0.6 m
# length: exact 1 in
# length: exact 1 in, diameter: exact 0.5 in
# length: exact 1 in, height: exact 8.5 in, depth: exact 4 in
# length: exact 1 in, width: exact 1 in, height: exact 4.8 in
# length: exact 1 in, width: exact 3 in
# length: exact 1 m
# length: exact 1 m, width: exact 0.5 in, thickness: exact 0.09375 in
# length: exact 1 m, width: exact 1 m, thickness: exact 15 mm
# length: exact 1 m, width: exact 15 mm
# length: exact 1.0 m
# length: exact 1.12 m
# length: exact 1.12 m, width: exact 2.52 m, height: exact 2.86 m
# length: exact 1.1875 in, width: exact 2.625 in
# length: exact 1.2 m
# length: exact 1.2 m, width: exact 1 m
# length: exact 1.2 m, width: exact 1.25 m
# length: exact 1.25 cm
# length: exact 1.25 in, diameter: exact 7.5 in
# length: exact 1.25 in, width: exact 0.375 in
# length: exact 1.25 mm
# length: exact 1.3 m, width: exact 1.2 m, height: exact 1.8 m
# length: exact 1.3 mm, width: exact 1.6 mm, height: exact 3.2 mm
# length: exact 1.34 in, width: exact 0.4375 in
# length: exact 1.36 in, width: exact 0.5 in, height: exact 2.5 in
# length: exact 1.375 in
# length: exact 1.4 in, width: exact 0.71 in, height: exact 0.35 in, weight: exact 0.15 oz
# length: exact 1.4 m, width: exact 1 m
# length: exact 1.5 cm, width: exact 4.5 cm
# length: exact 1.5 in
# length: exact 1.5 in, width: exact 0.75 in
# length: exact 1.5 in, width: exact 1.5 in
# length: exact 1.5 m
# length: exact 1.5 m, width: exact 100 mm, thickness: exact 22 mm
# length: exact 1.5625 in, width: exact 0.375 in
# length: exact 1.58 in, width: exact 0.82 in, height: exact 1.56 in, weight: exact 2.36 oz
# length: exact 1.6 in, width: exact 0.8 in, height: exact 1.5 in
# length: exact 1.6 m
# length: exact 1.6 m, width: exact 1 m
# length: exact 1.625 in, diameter: exact 0.141 in
# length: exact 1.7 in, width: exact 0.98 in, height: exact 0.035 in
# length: exact 1.75 in, width: exact 0.5 in
# length: exact 1.8 m
# length: exact 1.8 m, width: exact 1.25 m
# length: exact 1.87 in, width: exact 2.37 in
# length: exact 10 cm
# length: exact 10 cm, width: exact 10 cm, height: exact 2 cm, weight: exact 0.1 kg
# length: exact 10 cm, width: exact 2.5 cm
# length: exact 10 cm, width: exact 6 mm
# length: exact 10 cm, width: exact 7 cm
# length: exact 10 ft
# length: exact 10 ft, width: exact 5 ft
# length: exact 10 ft, width: exact 6 in
# length: exact 10 in
# length: exact 10 in, width: exact 1 in, height: exact 1 in
# length: exact 10 in, width: exact 10 in, height: exact 3 in
# length: exact 10 in, width: exact 3.5 in
# length: exact 10 in, width: exact 4.63 in
# length: exact 10 in, width: exact 5.5 in, height: exact 2.5 in, weight: exact 0.3 lbs
# length: exact 10 in, width: exact 6 in, height: exact 6 in
# length: exact 10 in, width: exact 61 in, height: exact 13 in, weight: exact 35 lbs
# length: exact 10 in, width: exact 7 in
# length: exact 10 in, width: exact 7 in, height: exact 2 in
# length: exact 10 in, width: exact 8 in, height: exact 2 in
# length: exact 10 m
# length: exact 10 mm
# length: exact 10 mm, width: exact 5 mm
# length: exact 10.24 in, width: exact 6.7 in, height: exact 6.82 in, weight: exact 5.5 kg
# length: exact 10.25 in
# length: exact 10.4 in, width: exact 5.5 in, height: exact 3.5 in
# length: exact 10.5 in, diameter: exact 1 in
# length: exact 10.5 in, width: exact 7.5 in
# length: exact 10.5 m
# length: exact 10.75 in, width: exact 5.5 in, height: exact 1 in
# length: exact 10.75 in, width: exact 5.5 in, height: exact 6 in
# length: exact 100 cm
# length: exact 100 cm, height: exact 50 cm
# length: exact 100 cm, width: exact 100 m
# length: exact 100 ft
# length: exact 100 in
# length: exact 100 m
# length: exact 100 mm
# length: exact 100 mm, volume: exact 12 ml
# length: exact 100 mm, weight: exact 100 g
# length: exact 100 mm, weight: exact 128 g
# length: exact 100 mm, width: exact 100 mm
# length: exact 100 mm, width: exact 16 mm
# length: exact 100 mm, width: exact 200 mm
# length: exact 100 mm, width: exact 70 mm
# length: exact 1000 ft
# length: exact 1000 m
# length: exact 101.6 mm, width: exact 38.1 mm
# length: exact 102 mm, width: exact 48 mm
# length: exact 1030 mm, width: exact 415 mm, height: exact 160 mm
# length: exact 105 mm, width: exact 230 mm
# length: exact 105 mm, width: exact 380 mm
# length: exact 108 cm, width: exact 108 cm
# length: exact 108 in, width: exact 38 in, height: exact 80 in, weight: exact 218 lbs
# length: exact 108 mm, diameter: exact 30 mm
# length: exact 11 cm, width: exact 1.5 cm, height: exact 9.5 cm
# length: exact 11 in
# length: exact 11 in, height: exact 9 in, depth: exact 3.5 in
# length: exact 11 in, width: exact 15 in
# length: exact 11 in, width: exact 17 in
# length: exact 11 in, width: exact 22 in, weight: exact 10 lbs
# length: exact 11 in, width: exact 5.5 in, thickness: exact 20 mm
# length: exact 11 in, width: exact 7 in, height: exact 5 in
# length: exact 11 in, width: exact 8 in, height: exact 1 in
# length: exact 11 in, width: exact 8.5 in
# length: exact 11 in, width: exact 9 in, height: exact 3.5 in, weight: exact 1 lbs
# length: exact 11.25 in, width: exact 4.25 in
# length: exact 11.25 in, width: exact 8.75 in, height: exact 4.25 in
# length: exact 11.5 cm
# length: exact 11.5 in, width: exact 9 in, thickness: exact 0.25 in
# length: exact 11.5 mm
# length: exact 11.5 mm, diameter: exact 3.75 mm
# length: exact 11.75 in, width: exact 13.25 in, thickness: exact 0.6 in
# length: exact 11.8 in, width: exact 5.9 in, height: exact 6.3 in, volume: exact 7 l
# length: exact 11.83 ft, width: exact 9.17 ft
# length: exact 11.92 m, width: exact 11.92 m, height: exact 3.32 m, volume: exact 445.568 m3
# length: exact 11.95 in, width: exact 8.38 in, thickness: exact 0.193 in
# length: exact 110 in, width: exact 60 in, height: exact 87 in, weight: exact 1200 lbs
# length: exact 110 mm, diameter: exact 50 mm
# length: exact 110 mm, width: exact 69 mm, height: exact 18 mm, weight: exact 0.153 kg
# length: exact 110.2 in, height: exact 110.2 in, width: exact 110.2 in
# length: exact 1100 mm, diameter: exact 4 mm
# length: exact 111.5 in, width: exact 7.5 in, depth: exact 4.5 in
# length: exact 112 cm, width: exact 71 cm
# length: exact 1130 mm
# length: exact 114 mm, width: exact 70 mm, height: exact 38 mm, weight: exact 370 g
# length: exact 115 cm
# length: exact 115 cm, width: exact 70 cm
# length: exact 12 cm
# length: exact 12 cm, width: exact 8 cm
# length: exact 12 ft
# length: exact 12 ft, diameter: exact 6 in
# length: exact 12 ft, width: exact 4 ft
# length: exact 12 ft, width: exact 6 ft, height: exact 6 ft
# length: exact 12 ft, width: exact 8 ft
# length: exact 12 in
# length: exact 12 in, height: exact 10.5 in, depth: exact 5 in
# length: exact 12 in, height: exact 15 in, depth: exact 6.5 in
# length: exact 12 in, height: exact 9.5 in, depth: exact 4.5 in
# length: exact 12 in, height: exact 9.5 in, depth: exact 5 in
# length: exact 12 in, width: exact 0.9375 in
# ...
# width: exact 13 in, depth: exact 8 in, height: exact 16.5 in
# width: exact 13 mm
# width: exact 13 mm, length: exact 305 mm
# width: exact 1340 mm
# width: exact 135 cm, depth: exact 51 cm, height: exact 98.5 cm
# width: exact 14 in, depth: exact 4 in, height: exact 9 in
# width: exact 14 in, depth: exact 9 in, height: exact 22 in
# width: exact 14 in, height: exact 11 in
# width: exact 14 in, length: exact 96 in
# width: exact 148 cm
# width: exact 15 in, height: exact 50 in
# width: exact 15 in, length: exact 20.25 in
# width: exact 15 in, length: exact 6000 ft
# width: exact 15 mm, height: exact 15 mm
# width: exact 15.3125 in, height: exact 14.875 in, length: exact 10.5 in
# width: exact 15.5 in
# width: exact 15.5 in, length: exact 31 in
# width: exact 150 cm
# width: exact 150 mm, depth: exact 74 mm, height: exact 210 mm
# width: exact 151 cm, depth: exact 75 cm, height: exact 74 cm
# width: exact 1510 mm
# width: exact 16 in
# width: exact 16 in, height: exact 22 in, depth: exact 9 in, weight: exact 1.7 lbs
# width: exact 16 in, length: exact 3500 ft
# width: exact 16.5 in, depth: exact 16.5 in, height: exact 11.5 in
# width: exact 16.5 in, depth: exact 3.5 in, height: exact 1.5 in
# width: exact 16.5 in, depth: exact 3.5 in, height: exact 11.5 in
# width: exact 16.5 in, depth: exact 9 in, height: exact 22 in
# width: exact 16.5 in, depth: exact 9 in, height: exact 22 in, weight: exact 12.5 lbs
# width: exact 1650 mm
# width: exact 17 in, length: exact 15 in
# width: exact 17 in, length: exact 51 in
# width: exact 17.5 in
# width: exact 175 mm, length: exact 150 m
# width: exact 18 in, depth: exact 12 in, height: exact 3 in
# width: exact 18 in, depth: exact 16 in, height: min 30 in, height: max 41 in
# width: exact 18 in, depth: exact 3.5 in, height: exact 13 in
# width: exact 18 in, depth: exact 60 in, height: exact 1 in
# width: exact 18 in, depth: exact 72 in, height: exact 1 in
# width: exact 18 in, height: exact 12 in
# width: exact 18 in, height: exact 34.5 in, depth: exact 24 in
# width: exact 18 in, height: max 5 in, height: min 1.5 in
# width: exact 18 in, length: exact 1500 ft
# width: exact 18.75 in, depth: exact 20.75 in, height: exact 29.5 in
# width: exact 180 mm, height: exact 410 mm
# width: exact 180 mm, height: exact 810 mm
# width: exact 180 mm, length: exact 810 mm
# width: exact 19 mm, length: exact 7.5 m
# width: exact 190 mm, length: exact 2525 mm, weight: exact 7.05 lbs
# width: exact 2 cm, length: exact 110 cm
# width: exact 2 in
# width: exact 2 in, height: exact 1.25 in
# width: exact 2 in, height: exact 2 in, length: exact 48 in
# width: exact 2 in, height: exact 2.5 in
# width: exact 2 in, height: exact 3 in
# width: exact 2 in, height: exact 4.5 in
# width: exact 2 m
# width: exact 2 mm, length: exact 180 mm
# width: exact 2 mm, length: exact 45 cm
# width: exact 2.25 in
# width: exact 2.25 in, length: exact 50 ft
# width: exact 2.25 in, length: exact 60 in, thickness: exact 0.05 in
# width: exact 2.3 in, height: exact 3.7 in, depth: exact 0.75 in
# width: exact 2.4 in, length: exact 5.6 in
# width: exact 2.72 m, length: exact 11 m
# width: exact 2.75 in, length: exact 11 in
# width: exact 2.75 in, length: exact 4.5 in
# width: exact 2.75 in, length: exact 8 in
# width: exact 20 cm, height: exact 6 cm, depth: exact 28 cm
# width: exact 20 ft, length: exact 90 ft
# width: exact 20 in, depth: exact 16 in, height: exact 3.5 in
# width: exact 20 in, depth: exact 17 in
# width: exact 20 in, depth: exact 20 in
# width: exact 20 in, length: exact 30 in
# width: exact 20 mm, depth: exact 20 mm, length: exact 50 mm
# width: exact 20 mm, length: exact 20 cm, weight: exact 0.05 kg
# width: exact 21 in
# width: exact 21 in, depth: exact 37 in, height: exact 8 in
# width: exact 21 in, height: exact 23 in
# width: exact 21 in, height: exact 48 in, weight: exact 84 lbs
# width: exact 21 in, height: exact 60 in, length: exact 86 in
# width: exact 21.5 in, height: exact 33.5 in, depth: exact 23.25 in
# width: exact 21.7 in, depth: exact 23.2 in, height: exact 32.5 in, weight: exact 16.5 lbs
# width: exact 215 mm, diameter: exact 50 in
# width: exact 22 in
# width: exact 22 in, depth: exact 16 in, height: exact 22 in
# width: exact 22 in, depth: exact 17 in
# width: exact 22 in, depth: exact 18 in, height: exact 51 in
# width: exact 22 in, depth: exact 26.44 in, height: exact 37.63 in
# width: exact 22 in, height: exact 18 in
# width: exact 22 in, height: exact 34 in, depth: exact 13 in
# width: exact 22 in, height: exact 34 in, depth: exact 13 in, weight: exact 18.3 lbs
# width: exact 22 mm, length: exact 5 m
# width: exact 22.5 in, height: exact 23.5 in
# width: exact 2230 mm, length: exact 4990 mm, height: exact 2490 mm
# width: exact 225 mm
# width: exact 23.4 in, depth: exact 24.7 in, height: exact 31.5 in
# width: exact 24 in
# width: exact 24 in, height: exact 18 in
# width: exact 24 in, height: exact 24 in
# width: exact 24 in, height: exact 36 in
# width: exact 24 in, thickness: exact 3 in
# width: exact 25 in, depth: exact 24 in, height: exact 30 in
# width: exact 25 mm, height: exact 25 mm
# width: exact 25 mm, length: exact 20 m
# width: exact 25.5 in, depth: exact 27 in, height: exact 37.63 in
# width: exact 250 cm, height: exact 250 cm
# width: exact 26.25 in, length: exact 116 in, weight: exact 47 lbs
# width: exact 26.88 in, height: exact 33.88 in
# width: exact 268 mm, depth: exact 110 mm, height: exact 340 mm, weight: exact 1.9 kg
# width: exact 27 in, depth: exact 18 in, height: min 12 in, height: max 18 in
# width: exact 27 in, height: exact 45 in, length: exact 60 in
# width: exact 273 mm, depth: exact 502 mm, height: exact 685 mm
# width: exact 275 in, diameter: exact 18 in
# width: exact 28 ft, length: exact 60 ft
# width: exact 28 in, depth: exact 15 in, height: exact 30 in
# width: exact 28 in, depth: exact 19.6 in, height: exact 62 in
# width: exact 28 in, height: exact 28 in
# width: exact 28 in, height: exact 47 in, depth: exact 29.5 in
# width: exact 28 in, length: exact 34 in
# width: exact 28 mm, length: exact 120 cm
# width: exact 28.5 in, depth: exact 24 in
# width: exact 3 ft, length: exact 10 ft
# width: exact 3 ft, length: exact 12 ft
# width: exact 3 ft, length: exact 3 ft, thickness: exact 0.5 in
# width: exact 3 in
# width: exact 3 in, height: exact 2 in, depth: exact 1.25 in
# width: exact 3 in, height: exact 4 in
# width: exact 3 in, height: exact 48 in, depth: exact 3 in
# width: exact 3 in, height: exact 5 in
# width: exact 3 in, length: exact 50 in
# width: exact 3 in, length: exact 7 ft
# width: exact 3 m
# width: exact 3.2 m
# width: exact 3.25 in, length: exact 22 in
# width: exact 3.33 in, length: exact 7 in
# width: exact 3.5 in, height: exact 2.25 in, length: exact 4.75 in, weight: exact 0.25 lbs
# width: exact 3.5 in, height: exact 7.34 in, depth: exact 4.9 in
# width: exact 3.5 in, length: exact 7 in
# width: exact 30 cm, length: exact 3 m
# width: exact 30 cm, length: exact 30 m
# width: exact 30 in
# width: exact 30 in, height: exact 72 in, depth: exact 54 in
# width: exact 30 in, length: exact 36 in
# width: exact 30 in, length: exact 72 in
# width: exact 30 mm, length: exact 2400 mm, weight: exact 1 lbs
# width: exact 306 mm, height: exact 161 mm, length: exact 84 mm
# width: exact 31.5 in
# width: exact 32 in, depth: exact 25 in, height: exact 44.5 in
# width: exact 32 in, depth: exact 26.5 in, height: exact 33 in
# width: exact 32 in, height: exact 22 in
# width: exact 32 in, height: exact 38.75 in
# width: exact 32 in, height: exact 43 in, depth: exact 35 in
# width: exact 3200 mm, diameter: exact 30 mm
# width: exact 33 in
# width: exact 35 in
# width: exact 35 in, length: exact 42 in
# width: exact 35 in, length: exact 80 in, height: exact 5 in
# width: exact 35 in, length: min 80 in, length: max 84 in
# width: exact 35.04 in, height: exact 26.5 in, depth: exact 13.46 in
# width: exact 36 in
# width: exact 36 in, depth: exact 15 in, height: exact 36 in
# width: exact 36 in, depth: exact 36 in, height: exact 1.25 in
# width: exact 36 in, height: exact 28.375 in, depth: exact 19.25 in
# width: exact 36 in, height: exact 40 in
# width: exact 36 in, height: exact 90 in
# width: exact 36 in, length: exact 72 in
# width: exact 37.5 cm, depth: exact 44.5 cm
# width: exact 380 mm
# width: exact 39 in, length: exact 80 in, height: exact 7 in
# width: exact 390 mm, height: exact 165 mm, weight: exact 1.5 kg
# width: exact 4 ft, depth: exact 2 ft, height: exact 2 in
# width: exact 4 ft, height: exact 8 ft, length: exact 24 ft
# width: exact 4 in
# width: exact 4 in, diameter: exact 12.5 in
# width: exact 4 in, height: exact 4 in, depth: exact 2 in
# width: exact 4 in, height: exact 6 in
# width: exact 4 in, length: exact 24 in, height: exact 30 in
# width: exact 4 in, length: exact 5 ft
# width: exact 4.0 mm
# width: exact 4.34 m, height: exact 4.95 m, length: exact 30 ft
# width: exact 4.5 mm
# width: exact 4.5 mm, height: exact 18 mm
# width: exact 4.75 in, height: exact 1.1875 in
# width: exact 40 in
# width: exact 40 mm
# width: exact 40 mm, diameter: exact 6 mm
# width: exact 40.7 cm
# width: exact 41.73 in, depth: exact 30.51 in, height: exact 29.13 in
# width: exact 42 in, depth: exact 42 in
# width: exact 42 in, length: exact 32 in
# width: exact 42 in, length: exact 80 in
# width: exact 42 in, length: exact 84 in, height: exact 9 in
# width: exact 42 mm
# width: exact 42.52 in, height: exact 13.19 in, depth: exact 8.9 in, weight: exact 60 lbs
# width: exact 44 in, height: exact 97 in
# width: exact 45.7 cm
# width: exact 450 mm, length: exact 496 mm, weight: exact 2.68 lbs
# width: exact 458 mm
# width: exact 46 in, depth: exact 12.75 in, height: exact 30 in
# width: exact 46 in, depth: exact 60 in
# width: exact 47 in, height: exact 32 in, length: exact 48 in
# width: exact 47 in, length: exact 35 in
# width: exact 47.75 in, height: exact 52 in, length: exact 69.8 in
# width: exact 477 mm, depth: exact 620 mm, height: exact 295 mm, weight: exact 31 kg
# width: exact 48 in
# width: exact 48 in, depth: exact 1.25 in
# width: exact 48 in, depth: exact 24 in, height: exact 68 in
# width: exact 48 in, depth: exact 29 in
# width: exact 48 in, height: exact 30 in
# width: exact 48 in, length: exact 12 in
# width: exact 48 in, length: exact 40 ft
# width: exact 48 in, length: exact 80 in
# width: exact 48 mm, length: exact 132 m
# width: exact 49.57 in, height: exact 14.25 in, depth: exact 11.1 in, weight: exact 78 lbs
# width: exact 5 in
# width: exact 5 in, depth: exact 18 in
# width: exact 5 in, height: exact 6 in
# width: exact 5 in, height: exact 7.19 in
# width: exact 5 in, height: exact 8 in
# width: exact 5 in, height: exact 9.375 in, weight: exact 0.3 lbs
# width: exact 5 mm, length: exact 6 m
# width: exact 5.0 cm, length: exact 5 m
# width: exact 5.0 in, height: exact 1.0 in, depth: exact 8.15 in
# width: exact 5.625 in, height: exact 1 in, depth: exact 0.75 in
# width: exact 5.6875 in, height: exact 2.625 in
# width: exact 50 mm, diameter: exact 10 mm
# width: exact 500 mm
# width: exact 52 in
# width: exact 52 in, height: exact 78 in
# width: exact 54 in
# width: exact 55 mm
# width: exact 55.5 cm, depth: exact 60 cm, height: exact 91 cm
# width: exact 56 in
# width: exact 56 in, weight: exact 215 g
# width: exact 560 mm
# width: exact 57 in
# width: exact 58 in
# width: exact 58 in, weight: exact 150 g
# width: exact 58 in, weight: exact 170 g
# width: exact 58 in, weight: exact 230 g
# width: exact 58 in, weight: exact 240 g
# width: exact 592 mm, height: exact 999 mm
# width: exact 592 mm, height: min 1000 mm, height: max 2000 mm
# width: exact 6 ft, height: exact 4 ft
# width: exact 6 in
# width: exact 6 in, length: exact 6 in, thickness: exact 0.25 in
# width: exact 6 mm, length: exact 402 mm
# width: exact 6.5 in, height: exact 4.5 in, length: exact 2 in
# width: exact 6.5 in, length: exact 11 in, height: exact 2 in
# width: exact 60 cm
# width: exact 60 cm, height: exact 999 mm
# width: exact 60 in
# width: exact 60 in, depth: exact 24 in
# width: exact 60 in, depth: exact 24 in, height: exact 62 in
# width: exact 60 in, depth: exact 30 in, height: min 29.75 in, height: max 37.25 in
# width: exact 60 in, depth: exact 78 in, height: exact 29.5 in
# width: exact 60 in, height: exact 45 in
# width: exact 600 mm, depth: exact 700 mm, height: exact 860 mm
# width: exact 61 cm
# width: exact 62 in, length: exact 51 in
# width: exact 630 mm, depth: exact 610 mm, height: exact 790 mm
# width: exact 65 mm, diameter: exact 12 mm
# width: exact 65 mm, length: exact 74 m
# width: exact 66 in
# width: exact 660 mm, depth: exact 440 mm, height: exact 685 mm
# width: exact 68 in, depth: exact 18 in, height: exact 36 in
# width: exact 7 in, height: exact 0.5 in
# width: exact 7 in, length: exact 15 in
# width: exact 7.5 in
# width: exact 7.7 in, length: exact 9.8 in
# width: exact 70.5 mm, height: exact 66.4 mm, depth: exact 192.7 mm, weight: exact 590 g
# width: exact 72 in
# width: exact 72 in, depth: exact 18 in
# width: exact 72 in, depth: exact 24 in, height: exact 30 in
# width: exact 72 in, depth: exact 78 in
# width: exact 72 in, height: exact 33.75 in, depth: exact 30 in
# width: exact 72 in, height: exact 34.25 in, depth: exact 21.75 in
# width: exact 75 mm
# width: exact 76 mm, height: exact 76 mm
# width: exact 76 mm, length: exact 50 mm
# width: exact 79 cm, volume: exact 487 l
# width: exact 8 cm, height: exact 11 cm
# width: exact 8 in
# width: exact 8.5 in, height: exact 16.5 in, depth: exact 15.75 in
# width: exact 800 mm
# width: exact 800 mm, height: min 1000 mm, height: max 2000 mm
# width: exact 810 mm
# width: exact 83 in, height: exact 33.5 in, depth: exact 23.25 in
# width: exact 87.2 in, height: exact 41.1 in, depth: exact 1.38 in
# width: exact 9 cm, height: exact 4 cm
# width: exact 9 in
# width: exact 9 in, diameter: exact 2.5 in
# width: exact 9 in, height: exact 9 in, depth: exact 2 in
# width: exact 9 in, height: exact 9.25 in
# width: exact 9 mm, length: exact 1220 mm, height: exact 2440 mm
# width: exact 9.6 in
# width: exact 90 cm
# width: exact 90 cm, volume: exact 569 l
# width: exact 90 mm, height: exact 260 mm
# width: exact 91.4 cm
# width: exact 96 in, depth: exact 43.8 in, height: exact 1.25 in, weight: exact 19.2 lbs
# width: exact 972 mm, height: exact 965 mm, depth: exact 33 mm
# width: min 0.13 in, width: max 0.154 in, height: min 0.104 in, height: max 0.154 in
# width: min 0.375 in, width: max 0.75 in
# width: min 1 in, width: max 3 in
# width: min 100 in, width: max 130 in
# width: min 105 mm, width: max 230 mm
# width: min 105 mm, width: max 380 mm
# width: min 1300 mm, width: max 1400 mm
# width: min 14 in, width: max 20 in, height: min 6 in, height: max 20 in
# width: min 16 in, width: max 24 in, height: min 28 in, height: max 41 in, weight: exact 8 lbs
# width: min 163.5 cm, width: max 194.5 cm, depth: exact 214 cm, height: exact 200 cm, weight: exact 35 kg
# width: min 180 mm, width: max 410 mm
# width: min 25 cm, width: max 40.5 cm
# width: min 25 mm, width: max 100 mm
# width: min 2800 mm, width: max 5600 mm
# width: min 3 in, width: max 20 in
# width: min 3 mm, width: max 50 mm, height: min 3 mm, height: max 50 mm
# width: min 3.5 in, width: max 4.5 in, height: min 9 in, height: max 14 in, thickness: exact 1.5 in
# width: min 3.75 in, width: max 4 in
# width: min 32 in, width: max 150 in
# width: min 40 mm, width: max 60 mm, depth: min 5.5 mm, depth: max 8.5 mm, height: min 10.5 mm, height: max 16.5 mm
# width: min 400 mm, width: max 500 mm
# width: min 48 in, width: max 120 in, depth: exact 30 in, height: exact 29 in
# width: min 5.5 in, width: max 7 in, height: exact 2 in
# width: min 50 mm, width: max 1200 mm
# width: min 50 mm, width: max 315 mm
# width: min 500 mm, width: max 599 mm
# width: min 51.2 in, width: max 63 in, length: exact 31.5 in
# width: min 52 in, width: max 54 in
# width: min 56 in, width: max 58 in
# width: min 592 mm, width: max 908 mm, height: exact 2000 mm
# width: min 600 mm, width: max 699 mm, height: exact 2000 mm
# width: min 600 mm, width: max 699 mm, height: min 1000 mm, height: max 2000 mm
# width: min 600 mm, width: max 799 mm, height: exact 2000 mm
# width: min 600 mm, width: max 900 mm
# width: min 62 mm, width: max 147 mm, height: exact 50 mm, length: min 17 mm, length: max 157 mm
# width: min 7 in, width: max 18 in, height: exact 12.5 in
# width: min 700 mm, width: max 1092 mm, length: exact 787 mm
# width: min 700 mm, width: max 799 mm, height: min 1000 mm, height: max 2000 mm
# width: min 8.5 in, width: max 22 in
# width: min 838 mm

# %%
def normalize_size_field(arr):
    if isinstance(arr, (list, np.ndarray)) and len(arr) > 0:
        parts = []
        for entry in arr:
            if isinstance(entry, dict):
                dim = normalize_text(entry.get('dimension', ''), remove_punct=False)
                val = normalize_text(entry.get('value', ''), remove_punct=False)
                unit = normalize_text(entry.get('unit', ''), remove_punct=False)
                typ = normalize_text(entry.get('type', ''), remove_punct=False)

                if dim and val and unit:
                    label = f"{dim}: {typ} {val} {unit}" if typ else f"{dim}: {val} {unit}"
                    parts.append(label.strip())
        return ', '.join(parts) if parts else np.nan
    return np.nan

df['size'] = df['size'].apply(normalize_size_field)

# %%
df
# Out:
#                                                   unspsc  \
# 0      sewing and stitchery and weaving equipment and...
# 1                 electric alternating current ac motors
# 2                     vehicle trim and exterior covering
# 3                                        pipe connectors
# 4                                                  doors
# ...                                                  ...
# 21941                                              other
# 21942                     processed and synthetic rubber
# 21943                            fresh cut rose bouquets
# 21944  vision correction or cosmetic eyewear and rela...
# 21945       chocolate and sugars and sweetening products
#
#                          root_domain  \
# 0                  studio-atcoat.com
# 1                     worm-gears.net
# 2               customcarcoverco.com
# 3                    plumbmaster.com
# 4                           sogno.in
# ...                              ...
# 21941                   dsbridal.com
# 21942               50735-in.all.biz
# 21943             lilyofthevalley.uk
# 21944  getcontactlensesonline.com.au
# 21945           malagoschocolate.com
#
#                                                 page_url  \
# 0          https://studio-atcoat.com/1372696759/?idx=510
# 1              https://worm-gears.net/tag/worm-gear-box/
# 2      https://customcarcoverco.com/collections/vendo...
# 3      https://www.plumbmaster.com/search?q=wolverine...
# 4      http://www.sogno.in/product-detail-CST-HGD-331...
# ...                                                  ...
# 21941  https://www.dsbridal.com/index.php/sale/veils....
# 21942               https://50735-in.all.biz/group-goods
# 21943  https://www.lilyofthevalley.uk/product/luxurio...
# 21944  https://getcontactlensesonline.com.au/brand/al...
# 21945  https://malagoschocolate.com/collections/ready...
#
#                                      product_title  \
# 0                        glimakra warping board 8m
# 1                          nmrv worm gearbox motor
# 2                         nissan r33 gtr car cover
# 3                                flexible fittings
# 4                   csthgd33103 hinged closet door
# ...                                            ...
# 21941                             1516 accessories
# 21942              general mechanical rubber goods
# 21943                        luxurious rose garden
# 21944  dailies aquacomfort plus multifocal 30 pack
# 21945  signature dark collection 85 dark chocolate
#
#                                          product_summary  \
# 0      the glimakra warping board is designed for use...
# 1      the nmrv worm gearbox motor is a highefficienc...
# 2      a custom car cover designed for the nissan r33...
# 3      flexible fittings for plumbing applications al...
# 4      the csthgd33103 hinged closet door is a meticu...
# ...                                                  ...
# 21941  accessories designed for sweet 1516 available ...
# 21942  a category of rubber goods designed for genera...
# 21943  the luxurious rose garden is a stunning floral...
# 21944  a pack of 30 dailies aquacomfort plus multifoc...
# 21945  a signature dark collection product from malag...
#
#                     product_name product_identifier  \
# 0                  warping board                NaN
# 1             worm gearbox motor                NaN
# 2                      car cover                NaN
# 3              flexible fittings                NaN
# 4             hinged closet door                NaN
# ...                          ...                ...
# 21941                accessories                NaN
# 21942               rubber goods                NaN
# 21943         floral arrangement                NaN
# 21944  multifocal contact lenses                NaN
# 21945             dark chocolate                NaN
#
#                             brand            intended_industries  \
# 0                             NaN                        textile
# 1                             NaN                     industrial
# 2                             NaN                     automotive
# 3                             NaN                       plumbing
# 4                             cst  construction, home appliances
# ...                           ...                            ...
# 21941                         NaN                         retail
# 21942                         NaN                  manufacturing
# 21943  lily of the valley florist                  gifts, retail
# 21944                     dailies                     healthcare
# 21945           malagos chocolate                  food beverage
#
#                                applicability materials  customization  \
# 0                       use with floor looms       NaN            NaN
# 1                    industrial applications       NaN            NaN
# 2      protecting vehicles from the elements       NaN            NaN
# 3                     plumbing installations       NaN            NaN
# 4                             closet storage       NaN            NaN
# ...                                      ...       ...            ...
# 21941             accessories for sweet 1516       NaN            NaN
# 21942                                    NaN    rubber            NaN
# 21943           decorative purposes, gifting       NaN            NaN
# 21944                      vision correction       NaN            NaN
# 21945                                    NaN       NaN            NaN
#
#                                             size  color  \
# 0                              length: exact 8 m    NaN
# 1                                            NaN    NaN
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 21941                      diameter: exact 15 in    NaN
# 21942                                        NaN    NaN
# 21943  width: exact 250 cm, height: exact 250 cm    NaN
# 21944                                        NaN    NaN
# 21945                                        NaN    NaN
#
#                                   miscellaneous_features  \
# 0                                                    NaN
# 1      good service life, high radiation efficiency, ...
# 2      personalization with custom brand logos graphi...
# 3       allows for movement, flexibility in installation
# 4      german engineering, italian craftsmanship, smo...
# ...                                                  ...
# 21941                        part of the sale collection
# 21942                                                NaN
# 21943    product images available in various resolutions
# 21944                                                NaN
# 21945                                                NaN
#
#                                              description  price_amount  \
# 0      the warping board is designed for use with flo...      159000.0
# 1      the worm gearbox motor is a highefficiency gea...           NaN
# 2      the car cover is a customdesigned cover tailor...           NaN
# 3      flexible fittings are designed for plumbing ap...           NaN
# 4      the hinged closet door is a storage solution c...           NaN
# ...                                                  ...           ...
# 21941  accessories are designed for use with sweet 15...           NaN
# 21942  rubber goods are designed for general mechanic...           NaN
# 21943  the floral arrangement offered by lily of the ...          45.0
# 21944  multifocal contact lenses are designed for dai...          82.0
# 21945  dark chocolate from malagos chocolate is a ric...           NaN
#
#       price_currency price_type
# 0                krw      exact
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
# ...              ...        ...
# 21941            NaN        NaN
# 21942            NaN        NaN
# 21943            gbp        min
# 21944            usd      exact
# 21945            NaN        NaN
#
# [21946 rows x 19 columns]

# %%
df.to_csv("cleaned_products.csv", index=False)
